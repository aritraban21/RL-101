# %% [markdown]
# Dependencies

# %%
import gymnasium as gym
import ale_py
import imageio.v2 as imageio

# %% [markdown]
# Training Code for Breakout

# %%
import gymnasium as gym
import torch
import torch.nn as nn
import numpy as np
import cv2
import random
import copy
import os
import imageio
from collections import deque
import ale_py

env = gym.make("BreakoutNoFrameskip-v4")

FIRE_ACTION = 1

class Q_Network(nn.Module):
    def __init__(self, output_size):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(4, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )
        self.fc = nn.Sequential(
            nn.Linear(64 * 7 * 7, 512),
            nn.ReLU(),
            nn.Linear(512, output_size)
        )

    def forward(self, x):
        x = x.float() / 255.0
        x = self.cnn(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

class ReplayBuffer:
    def __init__(self, capacity, device):
        self.buffer = deque(maxlen=capacity)
        self.device = device

    def add(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return (
            torch.tensor(np.stack(states), device=self.device),
            torch.tensor(actions, device=self.device),
            torch.tensor(rewards, dtype=torch.float32, device=self.device),
            torch.tensor(np.stack(next_states), device=self.device),
            torch.tensor(dones, dtype=torch.float32, device=self.device),
        )

    def len(self):
        return len(self.buffer)

def preprocess(obs, prev_obs):
    gray = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
    prev_gray = cv2.cvtColor(prev_obs, cv2.COLOR_RGB2GRAY)
    max_frame = np.maximum(gray, prev_gray)
    max_frame = max_frame[34:194, :]
    max_frame = cv2.resize(max_frame, (84, 84), interpolation=cv2.INTER_AREA)
    return max_frame.astype(np.uint8)

def step_with_skip(env, action, skip=4):
    total_reward = 0.0
    done = False
    last_info = {}
    last_obs = None
    for _ in range(skip):
        obs, r, terminated, truncated, info = env.step(action)
        total_reward += float(r)
        done = bool(terminated or truncated)
        last_info = info
        last_obs = obs
        if done:
            break
    return last_obs, total_reward, done, last_info

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

TOTAL_STEPS = 2_500_000
BUFFER_SIZE = 300_000
batch_size = 32
GAMMA = 0.99
LR = 1e-4

os.makedirs("models", exist_ok=True)
MODEL_PATH = "models/qnet_latest.pt"

TARGET_UPDATE_FREQ = 10_000
EPSILON_START = 0.8
EPSILON_MIN = 0.1
EPSILON_DECAY_START = 2_000
EPSILON_DECAY_STEPS = 1_750_000

FRAME_STACK = 4
MAX_EPISODE_STEPS = 10_000

SAVE_VIDEO_FREQ = 300
VIDEO_DIR = "videos"
os.makedirs(VIDEO_DIR, exist_ok=True)

q_net = Q_Network(env.action_space.n).to(DEVICE)
target_q_net = copy.deepcopy(q_net).to(DEVICE)
target_q_net.eval()

optimizer = torch.optim.Adam(q_net.parameters(), lr=LR)
loss_fn = nn.SmoothL1Loss()

buffer = ReplayBuffer(BUFFER_SIZE, DEVICE)

epsilon = EPSILON_START
global_steps = 0
episode_num = 1

while global_steps < TOTAL_STEPS:

    obs, info = env.reset()

    prev_obs = obs
    obs, _, _, _, info = env.step(FIRE_ACTION)
    prev_obs = obs
    obs, _, _, _, info = env.step(FIRE_ACTION)

    prev_lives = info.get("lives", None)

    obs_proc = preprocess(obs, prev_obs)
    frame_stack = deque([obs_proc] * FRAME_STACK, maxlen=FRAME_STACK)
    state = np.stack(frame_stack, axis=0)

    episode_reward = 0.0

    for _ in range(MAX_EPISODE_STEPS):
        global_steps += 1

        if random.random() < epsilon:
            action = random.choice([0, 2, 3])
        else:
            with torch.no_grad():
                q_vals = q_net(torch.tensor(state, device=DEVICE).unsqueeze(0))
                action = torch.argmax(q_vals).item()

        prev_obs = obs
        obs, reward, done, info = step_with_skip(env, action)
        total_reward = reward
        episode_reward += reward

        if (not done) and ("lives" in info) and (prev_lives is not None) and (info["lives"] < prev_lives):
            prev_obs_fire = obs
            obs, reward_fire, done_fire, info_fire = step_with_skip(env, FIRE_ACTION)
            total_reward += reward_fire
            episode_reward += reward_fire
            prev_obs = prev_obs_fire
            done = done_fire
            info = info_fire

        if "lives" in info:
            prev_lives = info["lives"]

        obs_proc = preprocess(obs, prev_obs)
        frame_stack.append(obs_proc)
        next_state = np.stack(frame_stack, axis=0)

        buffer.add(state, action, total_reward, next_state, done)
        state = next_state

        if buffer.len() >= batch_size and global_steps > 2_000:
            states, actions, rewards, next_states, dones = buffer.sample(batch_size)

            with torch.no_grad():
                next_q = target_q_net(next_states).max(1)[0]
                targets = rewards + GAMMA * next_q * (1 - dones)

            q = q_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)

            loss = loss_fn(q, targets)
            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(q_net.parameters(), 10.0)
            optimizer.step()

        if global_steps % TARGET_UPDATE_FREQ == 0:
            target_q_net.load_state_dict(q_net.state_dict())

        if global_steps > EPSILON_DECAY_START:
            decay_ratio = min(1.0, (global_steps - EPSILON_DECAY_START) / EPSILON_DECAY_STEPS)
            epsilon = max(EPSILON_MIN, EPSILON_START - decay_ratio * (EPSILON_START - EPSILON_MIN))

        if done:
            break

    if episode_num % SAVE_VIDEO_FREQ == 0:
        q_net.eval()
        frames = []
        eval_reward = 0.0

        obs, info = env.reset()
        prev_obs = obs
        obs, _, _, _, info = env.step(FIRE_ACTION)
        prev_obs = obs
        obs, _, _, _, info = env.step(FIRE_ACTION)

        prev_lives = info.get("lives", None)

        obs_proc = preprocess(obs, prev_obs)
        eval_stack = deque([obs_proc] * FRAME_STACK, maxlen=FRAME_STACK)
        eval_state = np.stack(eval_stack, axis=0)

        for _ in range(2000):
            frames.append(obs)

            with torch.no_grad():
                q_vals = q_net(torch.tensor(eval_state, device=DEVICE).unsqueeze(0))
                action = torch.argmax(q_vals).item()

            prev_obs = obs
            obs, r, done, info = step_with_skip(env, action)
            total_r = r
            eval_reward += r

            if (not done) and ("lives" in info) and (prev_lives is not None) and (info["lives"] < prev_lives):
                prev_obs_fire = obs
                obs, r_fire, done_fire, info_fire = step_with_skip(env, FIRE_ACTION)
                total_r += r_fire
                eval_reward += r_fire
                prev_obs = prev_obs_fire
                done = done_fire
                info = info_fire

            if "lives" in info:
                prev_lives = info["lives"]

            obs_proc = preprocess(obs, prev_obs)
            eval_stack.append(obs_proc)
            eval_state = np.stack(eval_stack, axis=0)

            if done:
                break

        path = f"{VIDEO_DIR}/episode_{episode_num}_steps_{global_steps}.mp4"
        imageio.mimsave(path, frames, fps=30)
        print("VIDEO SAVED:", path, "reward:", eval_reward)

        torch.save(
            {
                "episode": episode_num,
                "global_steps": global_steps,
                "model_state_dict": q_net.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "epsilon": epsilon,
            },
            MODEL_PATH
        )

        q_net.train()

    print(
        f"Episode {episode_num} | Reward {episode_reward} | Buffer length {buffer.len()} | Epsilon {epsilon:.3f} | Steps {global_steps}"
    )

    episode_num += 1
# Out:
# Episode 1 | Reward 1.0 | Buffer length 167 | Epsilon 0.800 | Steps 167
# Episode 2 | Reward 2.0 | Buffer length 364 | Epsilon 0.800 | Steps 364
# Episode 3 | Reward 1.0 | Buffer length 531 | Epsilon 0.800 | Steps 531
# Episode 4 | Reward 2.0 | Buffer length 746 | Epsilon 0.800 | Steps 746
# Episode 5 | Reward 1.0 | Buffer length 915 | Epsilon 0.800 | Steps 915
# Episode 6 | Reward 3.0 | Buffer length 1163 | Epsilon 0.800 | Steps 1163
# Episode 7 | Reward 0.0 | Buffer length 1283 | Epsilon 0.800 | Steps 1283
# Episode 8 | Reward 2.0 | Buffer length 1479 | Epsilon 0.800 | Steps 1479
# Episode 9 | Reward 1.0 | Buffer length 1646 | Epsilon 0.800 | Steps 1646
# Episode 10 | Reward 0.0 | Buffer length 1765 | Epsilon 0.800 | Steps 1765
# Episode 11 | Reward 2.0 | Buffer length 1958 | Epsilon 0.800 | Steps 1958
# Episode 12 | Reward 2.0 | Buffer length 2155 | Epsilon 0.800 | Steps 2155
# Episode 13 | Reward 0.0 | Buffer length 2274 | Epsilon 0.800 | Steps 2274
# Episode 14 | Reward 0.0 | Buffer length 2394 | Epsilon 0.800 | Steps 2394
# Episode 15 | Reward 0.0 | Buffer length 2514 | Epsilon 0.800 | Steps 2514
# Episode 16 | Reward 0.0 | Buffer length 2634 | Epsilon 0.800 | Steps 2634
# Episode 17 | Reward 0.0 | Buffer length 2754 | Epsilon 0.800 | Steps 2754
# Episode 18 | Reward 1.0 | Buffer length 2902 | Epsilon 0.800 | Steps 2902
# Episode 19 | Reward 0.0 | Buffer length 3021 | Epsilon 0.800 | Steps 3021
# Episode 20 | Reward 0.0 | Buffer length 3141 | Epsilon 0.800 | Steps 3141
# Episode 21 | Reward 1.0 | Buffer length 3310 | Epsilon 0.799 | Steps 3310
# Episode 22 | Reward 1.0 | Buffer length 3477 | Epsilon 0.799 | Steps 3477
# Episode 23 | Reward 3.0 | Buffer length 3688 | Epsilon 0.799 | Steps 3688
# Episode 24 | Reward 0.0 | Buffer length 3808 | Epsilon 0.799 | Steps 3808
# Episode 25 | Reward 0.0 | Buffer length 3928 | Epsilon 0.799 | Steps 3928
# Episode 26 | Reward 1.0 | Buffer length 4075 | Epsilon 0.799 | Steps 4075
# Episode 27 | Reward 0.0 | Buffer length 4195 | Epsilon 0.799 | Steps 4195
# Episode 28 | Reward 0.0 | Buffer length 4315 | Epsilon 0.799 | Steps 4315
# Episode 29 | Reward 2.0 | Buffer length 4492 | Epsilon 0.799 | Steps 4492
# Episode 30 | Reward 1.0 | Buffer length 4659 | Epsilon 0.799 | Steps 4659
# Episode 31 | Reward 0.0 | Buffer length 4779 | Epsilon 0.799 | Steps 4779
# Episode 32 | Reward 1.0 | Buffer length 4927 | Epsilon 0.799 | Steps 4927
# Episode 33 | Reward 0.0 | Buffer length 5047 | Epsilon 0.799 | Steps 5047
# Episode 34 | Reward 1.0 | Buffer length 5196 | Epsilon 0.799 | Steps 5196
# Episode 35 | Reward 0.0 | Buffer length 5316 | Epsilon 0.799 | Steps 5316
# Episode 36 | Reward 0.0 | Buffer length 5435 | Epsilon 0.799 | Steps 5435
# Episode 37 | Reward 2.0 | Buffer length 5632 | Epsilon 0.799 | Steps 5632
# Episode 38 | Reward 0.0 | Buffer length 5752 | Epsilon 0.798 | Steps 5752
# Episode 39 | Reward 0.0 | Buffer length 5872 | Epsilon 0.798 | Steps 5872
# Episode 40 | Reward 1.0 | Buffer length 6040 | Epsilon 0.798 | Steps 6040
# Episode 41 | Reward 0.0 | Buffer length 6159 | Epsilon 0.798 | Steps 6159
# Episode 42 | Reward 0.0 | Buffer length 6279 | Epsilon 0.798 | Steps 6279
# Episode 43 | Reward 1.0 | Buffer length 6448 | Epsilon 0.798 | Steps 6448
# Episode 44 | Reward 1.0 | Buffer length 6596 | Epsilon 0.798 | Steps 6596
# Episode 45 | Reward 3.0 | Buffer length 6817 | Epsilon 0.798 | Steps 6817
# Episode 46 | Reward 0.0 | Buffer length 6937 | Epsilon 0.798 | Steps 6937
# Episode 47 | Reward 0.0 | Buffer length 7057 | Epsilon 0.798 | Steps 7057
# Episode 48 | Reward 0.0 | Buffer length 7177 | Epsilon 0.798 | Steps 7177
# Episode 49 | Reward 0.0 | Buffer length 7296 | Epsilon 0.798 | Steps 7296
# Episode 50 | Reward 2.0 | Buffer length 7493 | Epsilon 0.798 | Steps 7493
# Episode 51 | Reward 1.0 | Buffer length 7662 | Epsilon 0.798 | Steps 7662
# Episode 52 | Reward 1.0 | Buffer length 7830 | Epsilon 0.798 | Steps 7830
# Episode 53 | Reward 1.0 | Buffer length 7996 | Epsilon 0.798 | Steps 7996
# Episode 54 | Reward 1.0 | Buffer length 8164 | Epsilon 0.798 | Steps 8164
# Episode 55 | Reward 1.0 | Buffer length 8312 | Epsilon 0.797 | Steps 8312
# Episode 56 | Reward 2.0 | Buffer length 8507 | Epsilon 0.797 | Steps 8507
# Episode 57 | Reward 0.0 | Buffer length 8627 | Epsilon 0.797 | Steps 8627
# Episode 58 | Reward 1.0 | Buffer length 8794 | Epsilon 0.797 | Steps 8794
# Episode 59 | Reward 0.0 | Buffer length 8914 | Epsilon 0.797 | Steps 8914
# Episode 60 | Reward 0.0 | Buffer length 9034 | Epsilon 0.797 | Steps 9034
# Episode 61 | Reward 5.0 | Buffer length 9345 | Epsilon 0.797 | Steps 9345
# Episode 62 | Reward 0.0 | Buffer length 9464 | Epsilon 0.797 | Steps 9464
# Episode 63 | Reward 1.0 | Buffer length 9612 | Epsilon 0.797 | Steps 9612
# Episode 64 | Reward 1.0 | Buffer length 9760 | Epsilon 0.797 | Steps 9760
# Episode 65 | Reward 1.0 | Buffer length 9929 | Epsilon 0.797 | Steps 9929
# Episode 66 | Reward 0.0 | Buffer length 10049 | Epsilon 0.797 | Steps 10049
# Episode 67 | Reward 0.0 | Buffer length 10169 | Epsilon 0.797 | Steps 10169
# Episode 68 | Reward 1.0 | Buffer length 10320 | Epsilon 0.797 | Steps 10320
# Episode 69 | Reward 0.0 | Buffer length 10440 | Epsilon 0.797 | Steps 10440
# Episode 70 | Reward 2.0 | Buffer length 10635 | Epsilon 0.797 | Steps 10635
# Episode 71 | Reward 1.0 | Buffer length 10804 | Epsilon 0.796 | Steps 10804
# Episode 72 | Reward 0.0 | Buffer length 10923 | Epsilon 0.796 | Steps 10923
# Episode 73 | Reward 1.0 | Buffer length 11091 | Epsilon 0.796 | Steps 11091
# Episode 74 | Reward 1.0 | Buffer length 11259 | Epsilon 0.796 | Steps 11259
# Episode 75 | Reward 3.0 | Buffer length 11483 | Epsilon 0.796 | Steps 11483
# Episode 76 | Reward 0.0 | Buffer length 11603 | Epsilon 0.796 | Steps 11603
# Episode 77 | Reward 2.0 | Buffer length 11818 | Epsilon 0.796 | Steps 11818
# Episode 78 | Reward 1.0 | Buffer length 11984 | Epsilon 0.796 | Steps 11984
# Episode 79 | Reward 1.0 | Buffer length 12132 | Epsilon 0.796 | Steps 12132
# Episode 80 | Reward 0.0 | Buffer length 12252 | Epsilon 0.796 | Steps 12252
# Episode 81 | Reward 1.0 | Buffer length 12400 | Epsilon 0.796 | Steps 12400
# Episode 82 | Reward 1.0 | Buffer length 12566 | Epsilon 0.796 | Steps 12566
# Episode 83 | Reward 2.0 | Buffer length 12742 | Epsilon 0.796 | Steps 12742
# Episode 84 | Reward 0.0 | Buffer length 12862 | Epsilon 0.796 | Steps 12862
# Episode 85 | Reward 2.0 | Buffer length 13037 | Epsilon 0.796 | Steps 13037
# Episode 86 | Reward 1.0 | Buffer length 13203 | Epsilon 0.796 | Steps 13203
# Episode 87 | Reward 1.0 | Buffer length 13370 | Epsilon 0.795 | Steps 13370
# Episode 88 | Reward 3.0 | Buffer length 13594 | Epsilon 0.795 | Steps 13594
# Episode 89 | Reward 0.0 | Buffer length 13714 | Epsilon 0.795 | Steps 13714
# Episode 90 | Reward 1.0 | Buffer length 13862 | Epsilon 0.795 | Steps 13862
# Episode 91 | Reward 1.0 | Buffer length 14031 | Epsilon 0.795 | Steps 14031
# Episode 92 | Reward 0.0 | Buffer length 14151 | Epsilon 0.795 | Steps 14151
# Episode 93 | Reward 1.0 | Buffer length 14318 | Epsilon 0.795 | Steps 14318
# Episode 94 | Reward 1.0 | Buffer length 14485 | Epsilon 0.795 | Steps 14485
# Episode 95 | Reward 0.0 | Buffer length 14605 | Epsilon 0.795 | Steps 14605
# Episode 96 | Reward 0.0 | Buffer length 14725 | Epsilon 0.795 | Steps 14725
# Episode 97 | Reward 0.0 | Buffer length 14845 | Epsilon 0.795 | Steps 14845
# Episode 98 | Reward 2.0 | Buffer length 15059 | Epsilon 0.795 | Steps 15059
# Episode 99 | Reward 1.0 | Buffer length 15207 | Epsilon 0.795 | Steps 15207
# Episode 100 | Reward 1.0 | Buffer length 15355 | Epsilon 0.795 | Steps 15355
# Episode 101 | Reward 1.0 | Buffer length 15503 | Epsilon 0.795 | Steps 15503
# Episode 102 | Reward 1.0 | Buffer length 15652 | Epsilon 0.795 | Steps 15652
# Episode 103 | Reward 3.0 | Buffer length 15896 | Epsilon 0.794 | Steps 15896
# Episode 104 | Reward 1.0 | Buffer length 16044 | Epsilon 0.794 | Steps 16044
# Episode 105 | Reward 0.0 | Buffer length 16164 | Epsilon 0.794 | Steps 16164
# Episode 106 | Reward 1.0 | Buffer length 16333 | Epsilon 0.794 | Steps 16333
# Episode 107 | Reward 1.0 | Buffer length 16482 | Epsilon 0.794 | Steps 16482
# Episode 108 | Reward 0.0 | Buffer length 16602 | Epsilon 0.794 | Steps 16602
# Episode 109 | Reward 0.0 | Buffer length 16722 | Epsilon 0.794 | Steps 16722
# Episode 110 | Reward 1.0 | Buffer length 16869 | Epsilon 0.794 | Steps 16869
# Episode 111 | Reward 2.0 | Buffer length 17067 | Epsilon 0.794 | Steps 17067
# Episode 112 | Reward 0.0 | Buffer length 17186 | Epsilon 0.794 | Steps 17186
# Episode 113 | Reward 1.0 | Buffer length 17335 | Epsilon 0.794 | Steps 17335
# Episode 114 | Reward 0.0 | Buffer length 17454 | Epsilon 0.794 | Steps 17454
# Episode 115 | Reward 0.0 | Buffer length 17574 | Epsilon 0.794 | Steps 17574
# Episode 116 | Reward 0.0 | Buffer length 17694 | Epsilon 0.794 | Steps 17694
# Episode 117 | Reward 0.0 | Buffer length 17814 | Epsilon 0.794 | Steps 17814
# Episode 118 | Reward 0.0 | Buffer length 17934 | Epsilon 0.794 | Steps 17934
# Episode 119 | Reward 0.0 | Buffer length 18054 | Epsilon 0.794 | Steps 18054
# Episode 120 | Reward 2.0 | Buffer length 18270 | Epsilon 0.793 | Steps 18270
# Episode 121 | Reward 0.0 | Buffer length 18390 | Epsilon 0.793 | Steps 18390
# Episode 122 | Reward 4.0 | Buffer length 18682 | Epsilon 0.793 | Steps 18682
# Episode 123 | Reward 1.0 | Buffer length 18850 | Epsilon 0.793 | Steps 18850
# Episode 124 | Reward 3.0 | Buffer length 19115 | Epsilon 0.793 | Steps 19115
# Episode 125 | Reward 2.0 | Buffer length 19310 | Epsilon 0.793 | Steps 19310
# Episode 126 | Reward 0.0 | Buffer length 19430 | Epsilon 0.793 | Steps 19430
# Episode 127 | Reward 0.0 | Buffer length 19550 | Epsilon 0.793 | Steps 19550
# Episode 128 | Reward 0.0 | Buffer length 19670 | Epsilon 0.793 | Steps 19670
# Episode 129 | Reward 2.0 | Buffer length 19866 | Epsilon 0.793 | Steps 19866
# Episode 130 | Reward 4.0 | Buffer length 20160 | Epsilon 0.793 | Steps 20160
# Episode 131 | Reward 0.0 | Buffer length 20280 | Epsilon 0.793 | Steps 20280
# Episode 132 | Reward 1.0 | Buffer length 20428 | Epsilon 0.793 | Steps 20428
# Episode 133 | Reward 1.0 | Buffer length 20576 | Epsilon 0.793 | Steps 20576
# Episode 134 | Reward 1.0 | Buffer length 20725 | Epsilon 0.793 | Steps 20725
# Episode 135 | Reward 0.0 | Buffer length 20845 | Epsilon 0.792 | Steps 20845
# Episode 136 | Reward 1.0 | Buffer length 20993 | Epsilon 0.792 | Steps 20993
# Episode 137 | Reward 1.0 | Buffer length 21162 | Epsilon 0.792 | Steps 21162
# Episode 138 | Reward 0.0 | Buffer length 21282 | Epsilon 0.792 | Steps 21282
# Episode 139 | Reward 0.0 | Buffer length 21402 | Epsilon 0.792 | Steps 21402
# Episode 140 | Reward 1.0 | Buffer length 21553 | Epsilon 0.792 | Steps 21553
# Episode 141 | Reward 1.0 | Buffer length 21722 | Epsilon 0.792 | Steps 21722
# Episode 142 | Reward 0.0 | Buffer length 21842 | Epsilon 0.792 | Steps 21842
# Episode 143 | Reward 2.0 | Buffer length 22058 | Epsilon 0.792 | Steps 22058
# Episode 144 | Reward 1.0 | Buffer length 22227 | Epsilon 0.792 | Steps 22227
# Episode 145 | Reward 1.0 | Buffer length 22375 | Epsilon 0.792 | Steps 22375
# Episode 146 | Reward 1.0 | Buffer length 22544 | Epsilon 0.792 | Steps 22544
# Episode 147 | Reward 1.0 | Buffer length 22692 | Epsilon 0.792 | Steps 22692
# Episode 148 | Reward 2.0 | Buffer length 22869 | Epsilon 0.792 | Steps 22869
# Episode 149 | Reward 2.0 | Buffer length 23066 | Epsilon 0.792 | Steps 23066
# Episode 150 | Reward 0.0 | Buffer length 23186 | Epsilon 0.792 | Steps 23186
# Episode 151 | Reward 1.0 | Buffer length 23334 | Epsilon 0.791 | Steps 23334
# Episode 152 | Reward 1.0 | Buffer length 23502 | Epsilon 0.791 | Steps 23502
# Episode 153 | Reward 0.0 | Buffer length 23622 | Epsilon 0.791 | Steps 23622
# Episode 154 | Reward 1.0 | Buffer length 23790 | Epsilon 0.791 | Steps 23790
# Episode 155 | Reward 0.0 | Buffer length 23910 | Epsilon 0.791 | Steps 23910
# Episode 156 | Reward 2.0 | Buffer length 24107 | Epsilon 0.791 | Steps 24107
# Episode 157 | Reward 1.0 | Buffer length 24256 | Epsilon 0.791 | Steps 24256
# Episode 158 | Reward 0.0 | Buffer length 24375 | Epsilon 0.791 | Steps 24375
# Episode 159 | Reward 0.0 | Buffer length 24495 | Epsilon 0.791 | Steps 24495
# Episode 160 | Reward 1.0 | Buffer length 24662 | Epsilon 0.791 | Steps 24662
# Episode 161 | Reward 1.0 | Buffer length 24831 | Epsilon 0.791 | Steps 24831
# Episode 162 | Reward 2.0 | Buffer length 25028 | Epsilon 0.791 | Steps 25028
# Episode 163 | Reward 1.0 | Buffer length 25176 | Epsilon 0.791 | Steps 25176
# Episode 164 | Reward 0.0 | Buffer length 25295 | Epsilon 0.791 | Steps 25295
# Episode 165 | Reward 1.0 | Buffer length 25442 | Epsilon 0.791 | Steps 25442
# Episode 166 | Reward 2.0 | Buffer length 25659 | Epsilon 0.791 | Steps 25659
# Episode 167 | Reward 0.0 | Buffer length 25779 | Epsilon 0.790 | Steps 25779
# Episode 168 | Reward 0.0 | Buffer length 25898 | Epsilon 0.790 | Steps 25898
# Episode 169 | Reward 0.0 | Buffer length 26018 | Epsilon 0.790 | Steps 26018
# Episode 170 | Reward 0.0 | Buffer length 26138 | Epsilon 0.790 | Steps 26138
# Episode 171 | Reward 0.0 | Buffer length 26258 | Epsilon 0.790 | Steps 26258
# Episode 172 | Reward 3.0 | Buffer length 26508 | Epsilon 0.790 | Steps 26508
# Episode 173 | Reward 0.0 | Buffer length 26628 | Epsilon 0.790 | Steps 26628
# Episode 174 | Reward 0.0 | Buffer length 26748 | Epsilon 0.790 | Steps 26748
# Episode 175 | Reward 4.0 | Buffer length 27038 | Epsilon 0.790 | Steps 27038
# Episode 176 | Reward 2.0 | Buffer length 27219 | Epsilon 0.790 | Steps 27219
# Episode 177 | Reward 0.0 | Buffer length 27339 | Epsilon 0.790 | Steps 27339
# Episode 178 | Reward 0.0 | Buffer length 27459 | Epsilon 0.790 | Steps 27459
# Episode 179 | Reward 0.0 | Buffer length 27578 | Epsilon 0.790 | Steps 27578
# Episode 180 | Reward 2.0 | Buffer length 27794 | Epsilon 0.790 | Steps 27794
# Episode 181 | Reward 1.0 | Buffer length 27962 | Epsilon 0.790 | Steps 27962
# Episode 182 | Reward 1.0 | Buffer length 28130 | Epsilon 0.790 | Steps 28130
# Episode 183 | Reward 0.0 | Buffer length 28250 | Epsilon 0.790 | Steps 28250
# Episode 184 | Reward 0.0 | Buffer length 28370 | Epsilon 0.789 | Steps 28370
# Episode 185 | Reward 0.0 | Buffer length 28490 | Epsilon 0.789 | Steps 28490
# Episode 186 | Reward 0.0 | Buffer length 28610 | Epsilon 0.789 | Steps 28610
# Episode 187 | Reward 1.0 | Buffer length 28779 | Epsilon 0.789 | Steps 28779
# Episode 188 | Reward 0.0 | Buffer length 28899 | Epsilon 0.789 | Steps 28899
# Episode 189 | Reward 1.0 | Buffer length 29048 | Epsilon 0.789 | Steps 29048
# Episode 190 | Reward 1.0 | Buffer length 29217 | Epsilon 0.789 | Steps 29217
# Episode 191 | Reward 0.0 | Buffer length 29337 | Epsilon 0.789 | Steps 29337
# Episode 192 | Reward 0.0 | Buffer length 29457 | Epsilon 0.789 | Steps 29457
# Episode 193 | Reward 1.0 | Buffer length 29606 | Epsilon 0.789 | Steps 29606
# Episode 194 | Reward 0.0 | Buffer length 29726 | Epsilon 0.789 | Steps 29726
# Episode 195 | Reward 1.0 | Buffer length 29895 | Epsilon 0.789 | Steps 29895
# Episode 196 | Reward 1.0 | Buffer length 30062 | Epsilon 0.789 | Steps 30062
# Episode 197 | Reward 1.0 | Buffer length 30210 | Epsilon 0.789 | Steps 30210
# Episode 198 | Reward 0.0 | Buffer length 30330 | Epsilon 0.789 | Steps 30330
# Episode 199 | Reward 1.0 | Buffer length 30497 | Epsilon 0.789 | Steps 30497
# Episode 200 | Reward 0.0 | Buffer length 30617 | Epsilon 0.789 | Steps 30617
# Episode 201 | Reward 0.0 | Buffer length 30736 | Epsilon 0.789 | Steps 30736
# Episode 202 | Reward 0.0 | Buffer length 30856 | Epsilon 0.788 | Steps 30856
# Episode 203 | Reward 1.0 | Buffer length 31023 | Epsilon 0.788 | Steps 31023
# Episode 204 | Reward 0.0 | Buffer length 31143 | Epsilon 0.788 | Steps 31143
# Episode 205 | Reward 0.0 | Buffer length 31262 | Epsilon 0.788 | Steps 31262
# Episode 206 | Reward 0.0 | Buffer length 31382 | Epsilon 0.788 | Steps 31382
# Episode 207 | Reward 1.0 | Buffer length 31531 | Epsilon 0.788 | Steps 31531
# Episode 208 | Reward 2.0 | Buffer length 31730 | Epsilon 0.788 | Steps 31730
# Episode 209 | Reward 0.0 | Buffer length 31850 | Epsilon 0.788 | Steps 31850
# Episode 210 | Reward 1.0 | Buffer length 32019 | Epsilon 0.788 | Steps 32019
# Episode 211 | Reward 0.0 | Buffer length 32139 | Epsilon 0.788 | Steps 32139
# Episode 212 | Reward 1.0 | Buffer length 32287 | Epsilon 0.788 | Steps 32287
# Episode 213 | Reward 2.0 | Buffer length 32481 | Epsilon 0.788 | Steps 32481
# Episode 214 | Reward 0.0 | Buffer length 32601 | Epsilon 0.788 | Steps 32601
# Episode 215 | Reward 0.0 | Buffer length 32720 | Epsilon 0.788 | Steps 32720
# Episode 216 | Reward 0.0 | Buffer length 32840 | Epsilon 0.788 | Steps 32840
# Episode 217 | Reward 1.0 | Buffer length 32988 | Epsilon 0.788 | Steps 32988
# Episode 218 | Reward 1.0 | Buffer length 33155 | Epsilon 0.788 | Steps 33155
# Episode 219 | Reward 0.0 | Buffer length 33275 | Epsilon 0.787 | Steps 33275
# Episode 220 | Reward 1.0 | Buffer length 33443 | Epsilon 0.787 | Steps 33443
# Episode 221 | Reward 1.0 | Buffer length 33610 | Epsilon 0.787 | Steps 33610
# Episode 222 | Reward 0.0 | Buffer length 33730 | Epsilon 0.787 | Steps 33730
# Episode 223 | Reward 1.0 | Buffer length 33879 | Epsilon 0.787 | Steps 33879
# Episode 224 | Reward 5.0 | Buffer length 34196 | Epsilon 0.787 | Steps 34196
# Episode 225 | Reward 1.0 | Buffer length 34365 | Epsilon 0.787 | Steps 34365
# Episode 226 | Reward 4.0 | Buffer length 34635 | Epsilon 0.787 | Steps 34635
# Episode 227 | Reward 0.0 | Buffer length 34755 | Epsilon 0.787 | Steps 34755
# Episode 228 | Reward 0.0 | Buffer length 34875 | Epsilon 0.787 | Steps 34875
# Episode 229 | Reward 2.0 | Buffer length 35089 | Epsilon 0.787 | Steps 35089
# Episode 230 | Reward 2.0 | Buffer length 35272 | Epsilon 0.787 | Steps 35272
# Episode 231 | Reward 0.0 | Buffer length 35392 | Epsilon 0.787 | Steps 35392
# Episode 232 | Reward 0.0 | Buffer length 35512 | Epsilon 0.787 | Steps 35512
# Episode 233 | Reward 0.0 | Buffer length 35632 | Epsilon 0.787 | Steps 35632
# Episode 234 | Reward 0.0 | Buffer length 35752 | Epsilon 0.786 | Steps 35752
# Episode 235 | Reward 1.0 | Buffer length 35900 | Epsilon 0.786 | Steps 35900
# Episode 236 | Reward 1.0 | Buffer length 36069 | Epsilon 0.786 | Steps 36069
# Episode 237 | Reward 2.0 | Buffer length 36266 | Epsilon 0.786 | Steps 36266
# Episode 238 | Reward 1.0 | Buffer length 36433 | Epsilon 0.786 | Steps 36433
# Episode 239 | Reward 1.0 | Buffer length 36581 | Epsilon 0.786 | Steps 36581
# Episode 240 | Reward 3.0 | Buffer length 36828 | Epsilon 0.786 | Steps 36828
# Episode 241 | Reward 0.0 | Buffer length 36948 | Epsilon 0.786 | Steps 36948
# Episode 242 | Reward 0.0 | Buffer length 37068 | Epsilon 0.786 | Steps 37068
# Episode 243 | Reward 1.0 | Buffer length 37234 | Epsilon 0.786 | Steps 37234
# Episode 244 | Reward 0.0 | Buffer length 37354 | Epsilon 0.786 | Steps 37354
# Episode 245 | Reward 1.0 | Buffer length 37522 | Epsilon 0.786 | Steps 37522
# Episode 246 | Reward 2.0 | Buffer length 37715 | Epsilon 0.786 | Steps 37715
# Episode 247 | Reward 2.0 | Buffer length 37911 | Epsilon 0.786 | Steps 37911
# Episode 248 | Reward 0.0 | Buffer length 38031 | Epsilon 0.786 | Steps 38031
# Episode 249 | Reward 0.0 | Buffer length 38151 | Epsilon 0.786 | Steps 38151
# Episode 250 | Reward 2.0 | Buffer length 38347 | Epsilon 0.785 | Steps 38347
# Episode 251 | Reward 0.0 | Buffer length 38467 | Epsilon 0.785 | Steps 38467
# Episode 252 | Reward 0.0 | Buffer length 38586 | Epsilon 0.785 | Steps 38586
# Episode 253 | Reward 2.0 | Buffer length 38783 | Epsilon 0.785 | Steps 38783
# Episode 254 | Reward 1.0 | Buffer length 38952 | Epsilon 0.785 | Steps 38952
# Episode 255 | Reward 2.0 | Buffer length 39148 | Epsilon 0.785 | Steps 39148
# Episode 256 | Reward 0.0 | Buffer length 39268 | Epsilon 0.785 | Steps 39268
# Episode 257 | Reward 0.0 | Buffer length 39387 | Epsilon 0.785 | Steps 39387
# Episode 258 | Reward 2.0 | Buffer length 39605 | Epsilon 0.785 | Steps 39605
# Episode 259 | Reward 0.0 | Buffer length 39725 | Epsilon 0.785 | Steps 39725
# Episode 260 | Reward 0.0 | Buffer length 39845 | Epsilon 0.785 | Steps 39845
# Episode 261 | Reward 0.0 | Buffer length 39965 | Epsilon 0.785 | Steps 39965
# Episode 262 | Reward 2.0 | Buffer length 40162 | Epsilon 0.785 | Steps 40162
# Episode 263 | Reward 2.0 | Buffer length 40360 | Epsilon 0.785 | Steps 40360
# Episode 264 | Reward 0.0 | Buffer length 40480 | Epsilon 0.785 | Steps 40480
# Episode 265 | Reward 0.0 | Buffer length 40600 | Epsilon 0.785 | Steps 40600
# Episode 266 | Reward 0.0 | Buffer length 40720 | Epsilon 0.785 | Steps 40720
# Episode 267 | Reward 1.0 | Buffer length 40889 | Epsilon 0.784 | Steps 40889
# Episode 268 | Reward 0.0 | Buffer length 41008 | Epsilon 0.784 | Steps 41008
# Episode 269 | Reward 2.0 | Buffer length 41185 | Epsilon 0.784 | Steps 41185
# Episode 270 | Reward 0.0 | Buffer length 41305 | Epsilon 0.784 | Steps 41305
# Episode 271 | Reward 0.0 | Buffer length 41424 | Epsilon 0.784 | Steps 41424
# Episode 272 | Reward 0.0 | Buffer length 41543 | Epsilon 0.784 | Steps 41543
# Episode 273 | Reward 4.0 | Buffer length 41823 | Epsilon 0.784 | Steps 41823
# Episode 274 | Reward 3.0 | Buffer length 42068 | Epsilon 0.784 | Steps 42068
# Episode 275 | Reward 0.0 | Buffer length 42188 | Epsilon 0.784 | Steps 42188
# Episode 276 | Reward 1.0 | Buffer length 42335 | Epsilon 0.784 | Steps 42335
# Episode 277 | Reward 0.0 | Buffer length 42455 | Epsilon 0.784 | Steps 42455
# Episode 278 | Reward 2.0 | Buffer length 42673 | Epsilon 0.784 | Steps 42673
# Episode 279 | Reward 0.0 | Buffer length 42793 | Epsilon 0.784 | Steps 42793
# Episode 280 | Reward 1.0 | Buffer length 42942 | Epsilon 0.784 | Steps 42942
# Episode 281 | Reward 1.0 | Buffer length 43108 | Epsilon 0.784 | Steps 43108
# Episode 282 | Reward 2.0 | Buffer length 43302 | Epsilon 0.783 | Steps 43302
# Episode 283 | Reward 2.0 | Buffer length 43495 | Epsilon 0.783 | Steps 43495
# Episode 284 | Reward 0.0 | Buffer length 43615 | Epsilon 0.783 | Steps 43615
# Episode 285 | Reward 1.0 | Buffer length 43764 | Epsilon 0.783 | Steps 43764
# Episode 286 | Reward 0.0 | Buffer length 43884 | Epsilon 0.783 | Steps 43884
# Episode 287 | Reward 0.0 | Buffer length 44004 | Epsilon 0.783 | Steps 44004
# Episode 288 | Reward 1.0 | Buffer length 44169 | Epsilon 0.783 | Steps 44169
# Episode 289 | Reward 0.0 | Buffer length 44288 | Epsilon 0.783 | Steps 44288
# Episode 290 | Reward 0.0 | Buffer length 44408 | Epsilon 0.783 | Steps 44408
# Episode 291 | Reward 0.0 | Buffer length 44528 | Epsilon 0.783 | Steps 44528
# Episode 292 | Reward 0.0 | Buffer length 44648 | Epsilon 0.783 | Steps 44648
# Episode 293 | Reward 1.0 | Buffer length 44796 | Epsilon 0.783 | Steps 44796
# Episode 294 | Reward 1.0 | Buffer length 44964 | Epsilon 0.783 | Steps 44964
# Episode 295 | Reward 2.0 | Buffer length 45157 | Epsilon 0.783 | Steps 45157
# Episode 296 | Reward 0.0 | Buffer length 45277 | Epsilon 0.783 | Steps 45277
# Episode 297 | Reward 2.0 | Buffer length 45492 | Epsilon 0.783 | Steps 45492
# Episode 298 | Reward 2.0 | Buffer length 45669 | Epsilon 0.783 | Steps 45669
# Episode 299 | Reward 1.0 | Buffer length 45836 | Epsilon 0.782 | Steps 45836
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# VIDEO SAVED: videos/episode_300_steps_45956.mp4 reward: 0.0
# Episode 300 | Reward 0.0 | Buffer length 45956 | Epsilon 0.782 | Steps 45956
# Episode 301 | Reward 0.0 | Buffer length 46076 | Epsilon 0.782 | Steps 46076
# Episode 302 | Reward 0.0 | Buffer length 46196 | Epsilon 0.782 | Steps 46196
# Episode 303 | Reward 0.0 | Buffer length 46316 | Epsilon 0.782 | Steps 46316
# Episode 304 | Reward 0.0 | Buffer length 46436 | Epsilon 0.782 | Steps 46436
# Episode 305 | Reward 1.0 | Buffer length 46585 | Epsilon 0.782 | Steps 46585
# Episode 306 | Reward 0.0 | Buffer length 46705 | Epsilon 0.782 | Steps 46705
# Episode 307 | Reward 1.0 | Buffer length 46853 | Epsilon 0.782 | Steps 46853
# Episode 308 | Reward 1.0 | Buffer length 47001 | Epsilon 0.782 | Steps 47001
# Episode 309 | Reward 0.0 | Buffer length 47121 | Epsilon 0.782 | Steps 47121
# Episode 310 | Reward 0.0 | Buffer length 47241 | Epsilon 0.782 | Steps 47241
# Episode 311 | Reward 0.0 | Buffer length 47361 | Epsilon 0.782 | Steps 47361
# Episode 312 | Reward 0.0 | Buffer length 47481 | Epsilon 0.782 | Steps 47481
# Episode 313 | Reward 0.0 | Buffer length 47599 | Epsilon 0.782 | Steps 47599
# Episode 314 | Reward 0.0 | Buffer length 47719 | Epsilon 0.782 | Steps 47719
# Episode 315 | Reward 2.0 | Buffer length 47915 | Epsilon 0.782 | Steps 47915
# Episode 316 | Reward 0.0 | Buffer length 48035 | Epsilon 0.782 | Steps 48035
# Episode 317 | Reward 0.0 | Buffer length 48155 | Epsilon 0.782 | Steps 48155
# Episode 318 | Reward 0.0 | Buffer length 48275 | Epsilon 0.781 | Steps 48275
# Episode 319 | Reward 1.0 | Buffer length 48443 | Epsilon 0.781 | Steps 48443
# Episode 320 | Reward 2.0 | Buffer length 48657 | Epsilon 0.781 | Steps 48657
# Episode 321 | Reward 0.0 | Buffer length 48777 | Epsilon 0.781 | Steps 48777
# Episode 322 | Reward 3.0 | Buffer length 48987 | Epsilon 0.781 | Steps 48987
# Episode 323 | Reward 0.0 | Buffer length 49107 | Epsilon 0.781 | Steps 49107
# Episode 324 | Reward 0.0 | Buffer length 49227 | Epsilon 0.781 | Steps 49227
# Episode 325 | Reward 3.0 | Buffer length 49432 | Epsilon 0.781 | Steps 49432
# Episode 326 | Reward 1.0 | Buffer length 49580 | Epsilon 0.781 | Steps 49580
# Episode 327 | Reward 1.0 | Buffer length 49746 | Epsilon 0.781 | Steps 49746
# Episode 328 | Reward 1.0 | Buffer length 49911 | Epsilon 0.781 | Steps 49911
# Episode 329 | Reward 0.0 | Buffer length 50030 | Epsilon 0.781 | Steps 50030
# Episode 330 | Reward 0.0 | Buffer length 50150 | Epsilon 0.781 | Steps 50150
# Episode 331 | Reward 1.0 | Buffer length 50298 | Epsilon 0.781 | Steps 50298
# Episode 332 | Reward 2.0 | Buffer length 50494 | Epsilon 0.781 | Steps 50494
# Episode 333 | Reward 0.0 | Buffer length 50614 | Epsilon 0.781 | Steps 50614
# Episode 334 | Reward 0.0 | Buffer length 50734 | Epsilon 0.781 | Steps 50734
# Episode 335 | Reward 0.0 | Buffer length 50854 | Epsilon 0.780 | Steps 50854
# Episode 336 | Reward 1.0 | Buffer length 51002 | Epsilon 0.780 | Steps 51002
# Episode 337 | Reward 1.0 | Buffer length 51169 | Epsilon 0.780 | Steps 51169
# Episode 338 | Reward 0.0 | Buffer length 51287 | Epsilon 0.780 | Steps 51287
# Episode 339 | Reward 1.0 | Buffer length 51435 | Epsilon 0.780 | Steps 51435
# Episode 340 | Reward 1.0 | Buffer length 51582 | Epsilon 0.780 | Steps 51582
# Episode 341 | Reward 0.0 | Buffer length 51702 | Epsilon 0.780 | Steps 51702
# Episode 342 | Reward 1.0 | Buffer length 51850 | Epsilon 0.780 | Steps 51850
# Episode 343 | Reward 0.0 | Buffer length 51969 | Epsilon 0.780 | Steps 51969
# Episode 344 | Reward 0.0 | Buffer length 52088 | Epsilon 0.780 | Steps 52088
# Episode 345 | Reward 0.0 | Buffer length 52207 | Epsilon 0.780 | Steps 52207
# Episode 346 | Reward 0.0 | Buffer length 52327 | Epsilon 0.780 | Steps 52327
# Episode 347 | Reward 3.0 | Buffer length 52572 | Epsilon 0.780 | Steps 52572
# Episode 348 | Reward 1.0 | Buffer length 52739 | Epsilon 0.780 | Steps 52739
# Episode 349 | Reward 1.0 | Buffer length 52886 | Epsilon 0.780 | Steps 52886
# Episode 350 | Reward 2.0 | Buffer length 53085 | Epsilon 0.780 | Steps 53085
# Episode 351 | Reward 0.0 | Buffer length 53205 | Epsilon 0.780 | Steps 53205
# Episode 352 | Reward 0.0 | Buffer length 53324 | Epsilon 0.779 | Steps 53324
# Episode 353 | Reward 0.0 | Buffer length 53443 | Epsilon 0.779 | Steps 53443
# Episode 354 | Reward 1.0 | Buffer length 53611 | Epsilon 0.779 | Steps 53611
# Episode 355 | Reward 0.0 | Buffer length 53730 | Epsilon 0.779 | Steps 53730
# Episode 356 | Reward 1.0 | Buffer length 53878 | Epsilon 0.779 | Steps 53878
# Episode 357 | Reward 0.0 | Buffer length 53998 | Epsilon 0.779 | Steps 53998
# Episode 358 | Reward 0.0 | Buffer length 54118 | Epsilon 0.779 | Steps 54118
# Episode 359 | Reward 1.0 | Buffer length 54267 | Epsilon 0.779 | Steps 54267
# Episode 360 | Reward 0.0 | Buffer length 54386 | Epsilon 0.779 | Steps 54386
# Episode 361 | Reward 1.0 | Buffer length 54535 | Epsilon 0.779 | Steps 54535
# Episode 362 | Reward 0.0 | Buffer length 54655 | Epsilon 0.779 | Steps 54655
# Episode 363 | Reward 0.0 | Buffer length 54775 | Epsilon 0.779 | Steps 54775
# Episode 364 | Reward 0.0 | Buffer length 54895 | Epsilon 0.779 | Steps 54895
# Episode 365 | Reward 0.0 | Buffer length 55015 | Epsilon 0.779 | Steps 55015
# Episode 366 | Reward 0.0 | Buffer length 55135 | Epsilon 0.779 | Steps 55135
# Episode 367 | Reward 0.0 | Buffer length 55255 | Epsilon 0.779 | Steps 55255
# Episode 368 | Reward 2.0 | Buffer length 55431 | Epsilon 0.779 | Steps 55431
# Episode 369 | Reward 0.0 | Buffer length 55551 | Epsilon 0.779 | Steps 55551
# Episode 370 | Reward 0.0 | Buffer length 55671 | Epsilon 0.779 | Steps 55671
# Episode 371 | Reward 0.0 | Buffer length 55789 | Epsilon 0.778 | Steps 55789
# Episode 372 | Reward 2.0 | Buffer length 55983 | Epsilon 0.778 | Steps 55983
# Episode 373 | Reward 0.0 | Buffer length 56102 | Epsilon 0.778 | Steps 56102
# Episode 374 | Reward 0.0 | Buffer length 56222 | Epsilon 0.778 | Steps 56222
# Episode 375 | Reward 0.0 | Buffer length 56342 | Epsilon 0.778 | Steps 56342
# Episode 376 | Reward 0.0 | Buffer length 56462 | Epsilon 0.778 | Steps 56462
# Episode 377 | Reward 1.0 | Buffer length 56630 | Epsilon 0.778 | Steps 56630
# Episode 378 | Reward 1.0 | Buffer length 56780 | Epsilon 0.778 | Steps 56780
# Episode 379 | Reward 1.0 | Buffer length 56928 | Epsilon 0.778 | Steps 56928
# Episode 380 | Reward 0.0 | Buffer length 57048 | Epsilon 0.778 | Steps 57048
# Episode 381 | Reward 1.0 | Buffer length 57196 | Epsilon 0.778 | Steps 57196
# Episode 382 | Reward 4.0 | Buffer length 57457 | Epsilon 0.778 | Steps 57457
# Episode 383 | Reward 3.0 | Buffer length 57701 | Epsilon 0.778 | Steps 57701
# Episode 384 | Reward 1.0 | Buffer length 57850 | Epsilon 0.778 | Steps 57850
# Episode 385 | Reward 0.0 | Buffer length 57970 | Epsilon 0.778 | Steps 57970
# Episode 386 | Reward 1.0 | Buffer length 58118 | Epsilon 0.778 | Steps 58118
# Episode 387 | Reward 0.0 | Buffer length 58238 | Epsilon 0.778 | Steps 58238
# Episode 388 | Reward 3.0 | Buffer length 58463 | Epsilon 0.777 | Steps 58463
# Episode 389 | Reward 3.0 | Buffer length 58705 | Epsilon 0.777 | Steps 58705
# Episode 390 | Reward 2.0 | Buffer length 58900 | Epsilon 0.777 | Steps 58900
# Episode 391 | Reward 1.0 | Buffer length 59048 | Epsilon 0.777 | Steps 59048
# Episode 392 | Reward 1.0 | Buffer length 59217 | Epsilon 0.777 | Steps 59217
# Episode 393 | Reward 0.0 | Buffer length 59337 | Epsilon 0.777 | Steps 59337
# Episode 394 | Reward 0.0 | Buffer length 59457 | Epsilon 0.777 | Steps 59457
# Episode 395 | Reward 1.0 | Buffer length 59605 | Epsilon 0.777 | Steps 59605
# Episode 396 | Reward 1.0 | Buffer length 59752 | Epsilon 0.777 | Steps 59752
# Episode 397 | Reward 1.0 | Buffer length 59900 | Epsilon 0.777 | Steps 59900
# Episode 398 | Reward 2.0 | Buffer length 60113 | Epsilon 0.777 | Steps 60113
# Episode 399 | Reward 1.0 | Buffer length 60279 | Epsilon 0.777 | Steps 60279
# Episode 400 | Reward 1.0 | Buffer length 60446 | Epsilon 0.777 | Steps 60446
# Episode 401 | Reward 4.0 | Buffer length 60719 | Epsilon 0.777 | Steps 60719
# Episode 402 | Reward 0.0 | Buffer length 60839 | Epsilon 0.776 | Steps 60839
# Episode 403 | Reward 0.0 | Buffer length 60959 | Epsilon 0.776 | Steps 60959
# Episode 404 | Reward 0.0 | Buffer length 61079 | Epsilon 0.776 | Steps 61079
# Episode 405 | Reward 1.0 | Buffer length 61247 | Epsilon 0.776 | Steps 61247
# Episode 406 | Reward 1.0 | Buffer length 61395 | Epsilon 0.776 | Steps 61395
# Episode 407 | Reward 1.0 | Buffer length 61544 | Epsilon 0.776 | Steps 61544
# Episode 408 | Reward 2.0 | Buffer length 61741 | Epsilon 0.776 | Steps 61741
# Episode 409 | Reward 3.0 | Buffer length 61989 | Epsilon 0.776 | Steps 61989
# Episode 410 | Reward 1.0 | Buffer length 62136 | Epsilon 0.776 | Steps 62136
# Episode 411 | Reward 2.0 | Buffer length 62312 | Epsilon 0.776 | Steps 62312
# Episode 412 | Reward 0.0 | Buffer length 62432 | Epsilon 0.776 | Steps 62432
# Episode 413 | Reward 1.0 | Buffer length 62598 | Epsilon 0.776 | Steps 62598
# Episode 414 | Reward 0.0 | Buffer length 62718 | Epsilon 0.776 | Steps 62718
# Episode 415 | Reward 1.0 | Buffer length 62885 | Epsilon 0.776 | Steps 62885
# Episode 416 | Reward 0.0 | Buffer length 63005 | Epsilon 0.776 | Steps 63005
# Episode 417 | Reward 1.0 | Buffer length 63171 | Epsilon 0.776 | Steps 63171
# Episode 418 | Reward 1.0 | Buffer length 63320 | Epsilon 0.775 | Steps 63320
# Episode 419 | Reward 2.0 | Buffer length 63537 | Epsilon 0.775 | Steps 63537
# Episode 420 | Reward 0.0 | Buffer length 63657 | Epsilon 0.775 | Steps 63657
# Episode 421 | Reward 1.0 | Buffer length 63804 | Epsilon 0.775 | Steps 63804
# Episode 422 | Reward 0.0 | Buffer length 63923 | Epsilon 0.775 | Steps 63923
# Episode 423 | Reward 2.0 | Buffer length 64100 | Epsilon 0.775 | Steps 64100
# Episode 424 | Reward 0.0 | Buffer length 64220 | Epsilon 0.775 | Steps 64220
# Episode 425 | Reward 0.0 | Buffer length 64340 | Epsilon 0.775 | Steps 64340
# Episode 426 | Reward 1.0 | Buffer length 64506 | Epsilon 0.775 | Steps 64506
# Episode 427 | Reward 2.0 | Buffer length 64683 | Epsilon 0.775 | Steps 64683
# Episode 428 | Reward 3.0 | Buffer length 64946 | Epsilon 0.775 | Steps 64946
# Episode 429 | Reward 1.0 | Buffer length 65115 | Epsilon 0.775 | Steps 65115
# Episode 430 | Reward 1.0 | Buffer length 65264 | Epsilon 0.775 | Steps 65264
# Episode 431 | Reward 1.0 | Buffer length 65431 | Epsilon 0.775 | Steps 65431
# Episode 432 | Reward 1.0 | Buffer length 65580 | Epsilon 0.775 | Steps 65580
# Episode 433 | Reward 0.0 | Buffer length 65699 | Epsilon 0.775 | Steps 65699
# Episode 434 | Reward 1.0 | Buffer length 65847 | Epsilon 0.774 | Steps 65847
# Episode 435 | Reward 0.0 | Buffer length 65967 | Epsilon 0.774 | Steps 65967
# Episode 436 | Reward 0.0 | Buffer length 66087 | Epsilon 0.774 | Steps 66087
# Episode 437 | Reward 0.0 | Buffer length 66206 | Epsilon 0.774 | Steps 66206
# Episode 438 | Reward 3.0 | Buffer length 66428 | Epsilon 0.774 | Steps 66428
# Episode 439 | Reward 0.0 | Buffer length 66548 | Epsilon 0.774 | Steps 66548
# Episode 440 | Reward 0.0 | Buffer length 66667 | Epsilon 0.774 | Steps 66667
# Episode 441 | Reward 1.0 | Buffer length 66815 | Epsilon 0.774 | Steps 66815
# Episode 442 | Reward 4.0 | Buffer length 67070 | Epsilon 0.774 | Steps 67070
# Episode 443 | Reward 0.0 | Buffer length 67190 | Epsilon 0.774 | Steps 67190
# Episode 444 | Reward 1.0 | Buffer length 67356 | Epsilon 0.774 | Steps 67356
# Episode 445 | Reward 2.0 | Buffer length 67571 | Epsilon 0.774 | Steps 67571
# Episode 446 | Reward 1.0 | Buffer length 67720 | Epsilon 0.774 | Steps 67720
# Episode 447 | Reward 0.0 | Buffer length 67840 | Epsilon 0.774 | Steps 67840
# Episode 448 | Reward 2.0 | Buffer length 68034 | Epsilon 0.774 | Steps 68034
# Episode 449 | Reward 2.0 | Buffer length 68229 | Epsilon 0.774 | Steps 68229
# Episode 450 | Reward 2.0 | Buffer length 68426 | Epsilon 0.773 | Steps 68426
# Episode 451 | Reward 1.0 | Buffer length 68575 | Epsilon 0.773 | Steps 68575
# Episode 452 | Reward 0.0 | Buffer length 68694 | Epsilon 0.773 | Steps 68694
# Episode 453 | Reward 1.0 | Buffer length 68841 | Epsilon 0.773 | Steps 68841
# Episode 454 | Reward 2.0 | Buffer length 69018 | Epsilon 0.773 | Steps 69018
# Episode 455 | Reward 2.0 | Buffer length 69195 | Epsilon 0.773 | Steps 69195
# Episode 456 | Reward 1.0 | Buffer length 69363 | Epsilon 0.773 | Steps 69363
# Episode 457 | Reward 1.0 | Buffer length 69530 | Epsilon 0.773 | Steps 69530
# Episode 458 | Reward 0.0 | Buffer length 69650 | Epsilon 0.773 | Steps 69650
# Episode 459 | Reward 2.0 | Buffer length 69846 | Epsilon 0.773 | Steps 69846
# Episode 460 | Reward 1.0 | Buffer length 69994 | Epsilon 0.773 | Steps 69994
# Episode 461 | Reward 0.0 | Buffer length 70114 | Epsilon 0.773 | Steps 70114
# Episode 462 | Reward 0.0 | Buffer length 70234 | Epsilon 0.773 | Steps 70234
# Episode 463 | Reward 0.0 | Buffer length 70354 | Epsilon 0.773 | Steps 70354
# Episode 464 | Reward 1.0 | Buffer length 70521 | Epsilon 0.773 | Steps 70521
# Episode 465 | Reward 5.0 | Buffer length 70817 | Epsilon 0.772 | Steps 70817
# Episode 466 | Reward 1.0 | Buffer length 70966 | Epsilon 0.772 | Steps 70966
# Episode 467 | Reward 2.0 | Buffer length 71181 | Epsilon 0.772 | Steps 71181
# Episode 468 | Reward 0.0 | Buffer length 71300 | Epsilon 0.772 | Steps 71300
# Episode 469 | Reward 0.0 | Buffer length 71420 | Epsilon 0.772 | Steps 71420
# Episode 470 | Reward 1.0 | Buffer length 71569 | Epsilon 0.772 | Steps 71569
# Episode 471 | Reward 1.0 | Buffer length 71737 | Epsilon 0.772 | Steps 71737
# Episode 472 | Reward 0.0 | Buffer length 71857 | Epsilon 0.772 | Steps 71857
# Episode 473 | Reward 2.0 | Buffer length 72072 | Epsilon 0.772 | Steps 72072
# Episode 474 | Reward 1.0 | Buffer length 72220 | Epsilon 0.772 | Steps 72220
# Episode 475 | Reward 1.0 | Buffer length 72369 | Epsilon 0.772 | Steps 72369
# Episode 476 | Reward 0.0 | Buffer length 72489 | Epsilon 0.772 | Steps 72489
# Episode 477 | Reward 0.0 | Buffer length 72609 | Epsilon 0.772 | Steps 72609
# Episode 478 | Reward 3.0 | Buffer length 72856 | Epsilon 0.772 | Steps 72856
# Episode 479 | Reward 1.0 | Buffer length 73004 | Epsilon 0.772 | Steps 73004
# Episode 480 | Reward 0.0 | Buffer length 73124 | Epsilon 0.772 | Steps 73124
# Episode 481 | Reward 2.0 | Buffer length 73301 | Epsilon 0.771 | Steps 73301
# Episode 482 | Reward 0.0 | Buffer length 73421 | Epsilon 0.771 | Steps 73421
# Episode 483 | Reward 0.0 | Buffer length 73540 | Epsilon 0.771 | Steps 73540
# Episode 484 | Reward 1.0 | Buffer length 73709 | Epsilon 0.771 | Steps 73709
# Episode 485 | Reward 2.0 | Buffer length 73907 | Epsilon 0.771 | Steps 73907
# Episode 486 | Reward 3.0 | Buffer length 74152 | Epsilon 0.771 | Steps 74152
# Episode 487 | Reward 2.0 | Buffer length 74351 | Epsilon 0.771 | Steps 74351
# Episode 488 | Reward 0.0 | Buffer length 74471 | Epsilon 0.771 | Steps 74471
# Episode 489 | Reward 3.0 | Buffer length 74739 | Epsilon 0.771 | Steps 74739
# Episode 490 | Reward 0.0 | Buffer length 74859 | Epsilon 0.771 | Steps 74859
# Episode 491 | Reward 3.0 | Buffer length 75068 | Epsilon 0.771 | Steps 75068
# Episode 492 | Reward 1.0 | Buffer length 75235 | Epsilon 0.771 | Steps 75235
# Episode 493 | Reward 0.0 | Buffer length 75355 | Epsilon 0.771 | Steps 75355
# Episode 494 | Reward 0.0 | Buffer length 75475 | Epsilon 0.771 | Steps 75475
# Episode 495 | Reward 0.0 | Buffer length 75594 | Epsilon 0.771 | Steps 75594
# Episode 496 | Reward 0.0 | Buffer length 75714 | Epsilon 0.771 | Steps 75714
# Episode 497 | Reward 1.0 | Buffer length 75883 | Epsilon 0.770 | Steps 75883
# Episode 498 | Reward 1.0 | Buffer length 76032 | Epsilon 0.770 | Steps 76032
# Episode 499 | Reward 0.0 | Buffer length 76151 | Epsilon 0.770 | Steps 76151
# Episode 500 | Reward 0.0 | Buffer length 76270 | Epsilon 0.770 | Steps 76270
# Episode 501 | Reward 2.0 | Buffer length 76468 | Epsilon 0.770 | Steps 76468
# Episode 502 | Reward 0.0 | Buffer length 76587 | Epsilon 0.770 | Steps 76587
# Episode 503 | Reward 2.0 | Buffer length 76764 | Epsilon 0.770 | Steps 76764
# Episode 504 | Reward 1.0 | Buffer length 76932 | Epsilon 0.770 | Steps 76932
# Episode 505 | Reward 3.0 | Buffer length 77179 | Epsilon 0.770 | Steps 77179
# Episode 506 | Reward 3.0 | Buffer length 77423 | Epsilon 0.770 | Steps 77423
# Episode 507 | Reward 2.0 | Buffer length 77641 | Epsilon 0.770 | Steps 77641
# Episode 508 | Reward 0.0 | Buffer length 77761 | Epsilon 0.770 | Steps 77761
# Episode 509 | Reward 0.0 | Buffer length 77880 | Epsilon 0.770 | Steps 77880
# Episode 510 | Reward 1.0 | Buffer length 78049 | Epsilon 0.770 | Steps 78049
# Episode 511 | Reward 1.0 | Buffer length 78198 | Epsilon 0.770 | Steps 78198
# Episode 512 | Reward 3.0 | Buffer length 78442 | Epsilon 0.769 | Steps 78442
# Episode 513 | Reward 1.0 | Buffer length 78591 | Epsilon 0.769 | Steps 78591
# Episode 514 | Reward 0.0 | Buffer length 78711 | Epsilon 0.769 | Steps 78711
# Episode 515 | Reward 1.0 | Buffer length 78878 | Epsilon 0.769 | Steps 78878
# Episode 516 | Reward 0.0 | Buffer length 78998 | Epsilon 0.769 | Steps 78998
# Episode 517 | Reward 0.0 | Buffer length 79118 | Epsilon 0.769 | Steps 79118
# Episode 518 | Reward 0.0 | Buffer length 79238 | Epsilon 0.769 | Steps 79238
# Episode 519 | Reward 0.0 | Buffer length 79358 | Epsilon 0.769 | Steps 79358
# Episode 520 | Reward 0.0 | Buffer length 79477 | Epsilon 0.769 | Steps 79477
# Episode 521 | Reward 0.0 | Buffer length 79596 | Epsilon 0.769 | Steps 79596
# Episode 522 | Reward 0.0 | Buffer length 79715 | Epsilon 0.769 | Steps 79715
# Episode 523 | Reward 0.0 | Buffer length 79835 | Epsilon 0.769 | Steps 79835
# Episode 524 | Reward 0.0 | Buffer length 79954 | Epsilon 0.769 | Steps 79954
# Episode 525 | Reward 0.0 | Buffer length 80074 | Epsilon 0.769 | Steps 80074
# Episode 526 | Reward 0.0 | Buffer length 80194 | Epsilon 0.769 | Steps 80194
# Episode 527 | Reward 2.0 | Buffer length 80408 | Epsilon 0.769 | Steps 80408
# Episode 528 | Reward 1.0 | Buffer length 80577 | Epsilon 0.769 | Steps 80577
# Episode 529 | Reward 0.0 | Buffer length 80696 | Epsilon 0.769 | Steps 80696
# Episode 530 | Reward 2.0 | Buffer length 80910 | Epsilon 0.768 | Steps 80910
# Episode 531 | Reward 0.0 | Buffer length 81030 | Epsilon 0.768 | Steps 81030
# Episode 532 | Reward 0.0 | Buffer length 81150 | Epsilon 0.768 | Steps 81150
# Episode 533 | Reward 0.0 | Buffer length 81270 | Epsilon 0.768 | Steps 81270
# Episode 534 | Reward 0.0 | Buffer length 81389 | Epsilon 0.768 | Steps 81389
# Episode 535 | Reward 1.0 | Buffer length 81557 | Epsilon 0.768 | Steps 81557
# Episode 536 | Reward 0.0 | Buffer length 81677 | Epsilon 0.768 | Steps 81677
# Episode 537 | Reward 1.0 | Buffer length 81842 | Epsilon 0.768 | Steps 81842
# Episode 538 | Reward 1.0 | Buffer length 82009 | Epsilon 0.768 | Steps 82009
# Episode 539 | Reward 3.0 | Buffer length 82215 | Epsilon 0.768 | Steps 82215
# Episode 540 | Reward 2.0 | Buffer length 82432 | Epsilon 0.768 | Steps 82432
# Episode 541 | Reward 1.0 | Buffer length 82601 | Epsilon 0.768 | Steps 82601
# Episode 542 | Reward 0.0 | Buffer length 82720 | Epsilon 0.768 | Steps 82720
# Episode 543 | Reward 0.0 | Buffer length 82840 | Epsilon 0.768 | Steps 82840
# Episode 544 | Reward 1.0 | Buffer length 83008 | Epsilon 0.768 | Steps 83008
# Episode 545 | Reward 0.0 | Buffer length 83127 | Epsilon 0.768 | Steps 83127
# Episode 546 | Reward 2.0 | Buffer length 83343 | Epsilon 0.767 | Steps 83343
# Episode 547 | Reward 5.0 | Buffer length 83690 | Epsilon 0.767 | Steps 83690
# Episode 548 | Reward 1.0 | Buffer length 83838 | Epsilon 0.767 | Steps 83838
# Episode 549 | Reward 0.0 | Buffer length 83957 | Epsilon 0.767 | Steps 83957
# Episode 550 | Reward 2.0 | Buffer length 84173 | Epsilon 0.767 | Steps 84173
# Episode 551 | Reward 3.0 | Buffer length 84398 | Epsilon 0.767 | Steps 84398
# Episode 552 | Reward 2.0 | Buffer length 84594 | Epsilon 0.767 | Steps 84594
# Episode 553 | Reward 0.0 | Buffer length 84714 | Epsilon 0.767 | Steps 84714
# Episode 554 | Reward 1.0 | Buffer length 84882 | Epsilon 0.767 | Steps 84882
# Episode 555 | Reward 1.0 | Buffer length 85031 | Epsilon 0.767 | Steps 85031
# Episode 556 | Reward 1.0 | Buffer length 85179 | Epsilon 0.767 | Steps 85179
# Episode 557 | Reward 0.0 | Buffer length 85299 | Epsilon 0.767 | Steps 85299
# Episode 558 | Reward 3.0 | Buffer length 85529 | Epsilon 0.767 | Steps 85529
# Episode 559 | Reward 1.0 | Buffer length 85676 | Epsilon 0.767 | Steps 85676
# Episode 560 | Reward 0.0 | Buffer length 85795 | Epsilon 0.766 | Steps 85795
# Episode 561 | Reward 0.0 | Buffer length 85915 | Epsilon 0.766 | Steps 85915
# Episode 562 | Reward 3.0 | Buffer length 86180 | Epsilon 0.766 | Steps 86180
# Episode 563 | Reward 1.0 | Buffer length 86347 | Epsilon 0.766 | Steps 86347
# Episode 564 | Reward 1.0 | Buffer length 86516 | Epsilon 0.766 | Steps 86516
# Episode 565 | Reward 0.0 | Buffer length 86636 | Epsilon 0.766 | Steps 86636
# Episode 566 | Reward 0.0 | Buffer length 86756 | Epsilon 0.766 | Steps 86756
# Episode 567 | Reward 1.0 | Buffer length 86922 | Epsilon 0.766 | Steps 86922
# Episode 568 | Reward 0.0 | Buffer length 87041 | Epsilon 0.766 | Steps 87041
# Episode 569 | Reward 0.0 | Buffer length 87160 | Epsilon 0.766 | Steps 87160
# Episode 570 | Reward 0.0 | Buffer length 87280 | Epsilon 0.766 | Steps 87280
# Episode 571 | Reward 0.0 | Buffer length 87400 | Epsilon 0.766 | Steps 87400
# Episode 572 | Reward 3.0 | Buffer length 87648 | Epsilon 0.766 | Steps 87648
# Episode 573 | Reward 1.0 | Buffer length 87796 | Epsilon 0.766 | Steps 87796
# Episode 574 | Reward 1.0 | Buffer length 87944 | Epsilon 0.766 | Steps 87944
# Episode 575 | Reward 2.0 | Buffer length 88141 | Epsilon 0.766 | Steps 88141
# Episode 576 | Reward 0.0 | Buffer length 88261 | Epsilon 0.765 | Steps 88261
# Episode 577 | Reward 0.0 | Buffer length 88381 | Epsilon 0.765 | Steps 88381
# Episode 578 | Reward 1.0 | Buffer length 88550 | Epsilon 0.765 | Steps 88550
# Episode 579 | Reward 1.0 | Buffer length 88716 | Epsilon 0.765 | Steps 88716
# Episode 580 | Reward 0.0 | Buffer length 88836 | Epsilon 0.765 | Steps 88836
# Episode 581 | Reward 2.0 | Buffer length 89013 | Epsilon 0.765 | Steps 89013
# Episode 582 | Reward 0.0 | Buffer length 89133 | Epsilon 0.765 | Steps 89133
# Episode 583 | Reward 0.0 | Buffer length 89253 | Epsilon 0.765 | Steps 89253
# Episode 584 | Reward 0.0 | Buffer length 89373 | Epsilon 0.765 | Steps 89373
# Episode 585 | Reward 1.0 | Buffer length 89522 | Epsilon 0.765 | Steps 89522
# Episode 586 | Reward 0.0 | Buffer length 89641 | Epsilon 0.765 | Steps 89641
# Episode 587 | Reward 0.0 | Buffer length 89760 | Epsilon 0.765 | Steps 89760
# Episode 588 | Reward 2.0 | Buffer length 89956 | Epsilon 0.765 | Steps 89956
# Episode 589 | Reward 0.0 | Buffer length 90075 | Epsilon 0.765 | Steps 90075
# Episode 590 | Reward 1.0 | Buffer length 90241 | Epsilon 0.765 | Steps 90241
# Episode 591 | Reward 1.0 | Buffer length 90407 | Epsilon 0.765 | Steps 90407
# Episode 592 | Reward 0.0 | Buffer length 90527 | Epsilon 0.765 | Steps 90527
# Episode 593 | Reward 0.0 | Buffer length 90647 | Epsilon 0.765 | Steps 90647
# Episode 594 | Reward 1.0 | Buffer length 90795 | Epsilon 0.764 | Steps 90795
# Episode 595 | Reward 2.0 | Buffer length 90989 | Epsilon 0.764 | Steps 90989
# Episode 596 | Reward 0.0 | Buffer length 91109 | Epsilon 0.764 | Steps 91109
# Episode 597 | Reward 2.0 | Buffer length 91305 | Epsilon 0.764 | Steps 91305
# Episode 598 | Reward 1.0 | Buffer length 91453 | Epsilon 0.764 | Steps 91453
# Episode 599 | Reward 0.0 | Buffer length 91573 | Epsilon 0.764 | Steps 91573
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# VIDEO SAVED: videos/episode_600_steps_91742.mp4 reward: 0.0
# Episode 600 | Reward 1.0 | Buffer length 91742 | Epsilon 0.764 | Steps 91742
# Episode 601 | Reward 0.0 | Buffer length 91861 | Epsilon 0.764 | Steps 91861
# Episode 602 | Reward 1.0 | Buffer length 92009 | Epsilon 0.764 | Steps 92009
# Episode 603 | Reward 2.0 | Buffer length 92206 | Epsilon 0.764 | Steps 92206
# Episode 604 | Reward 0.0 | Buffer length 92326 | Epsilon 0.764 | Steps 92326
# Episode 605 | Reward 0.0 | Buffer length 92446 | Epsilon 0.764 | Steps 92446
# Episode 606 | Reward 0.0 | Buffer length 92565 | Epsilon 0.764 | Steps 92565
# Episode 607 | Reward 0.0 | Buffer length 92683 | Epsilon 0.764 | Steps 92683
# Episode 608 | Reward 2.0 | Buffer length 92878 | Epsilon 0.764 | Steps 92878
# Episode 609 | Reward 0.0 | Buffer length 92996 | Epsilon 0.764 | Steps 92996
# Episode 610 | Reward 1.0 | Buffer length 93144 | Epsilon 0.764 | Steps 93144
# Episode 611 | Reward 3.0 | Buffer length 93407 | Epsilon 0.763 | Steps 93407
# Episode 612 | Reward 0.0 | Buffer length 93527 | Epsilon 0.763 | Steps 93527
# Episode 613 | Reward 1.0 | Buffer length 93675 | Epsilon 0.763 | Steps 93675
# Episode 614 | Reward 0.0 | Buffer length 93795 | Epsilon 0.763 | Steps 93795
# Episode 615 | Reward 1.0 | Buffer length 93962 | Epsilon 0.763 | Steps 93962
# Episode 616 | Reward 2.0 | Buffer length 94175 | Epsilon 0.763 | Steps 94175
# ...
# Episode 7362 | Reward 12.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2435907
# Episode 7363 | Reward 29.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2436343
# Episode 7364 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2436635
# Episode 7365 | Reward 228.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2437188
# Episode 7366 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2437495
# Episode 7367 | Reward 36.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2437941
# Episode 7368 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2438148
# Episode 7369 | Reward 14.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2438525
# Episode 7370 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2438761
# Episode 7371 | Reward 12.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2439039
# Episode 7372 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2439274
# Episode 7373 | Reward 292.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2440051
# Episode 7374 | Reward 20.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2440396
# Episode 7375 | Reward 18.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2440770
# Episode 7376 | Reward 229.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2441306
# Episode 7377 | Reward 6.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2441641
# Episode 7378 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2441847
# Episode 7379 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2442053
# Episode 7380 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2442289
# Episode 7381 | Reward 232.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2442880
# Episode 7382 | Reward 40.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2443383
# Episode 7383 | Reward 5.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2443672
# Episode 7384 | Reward 9.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2443993
# Episode 7385 | Reward 9.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2444296
# Episode 7386 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2444716
# Episode 7387 | Reward 5.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2444980
# Episode 7388 | Reward 7.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2445223
# Episode 7389 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2445429
# Episode 7390 | Reward 16.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2445895
# Episode 7391 | Reward 2.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2446072
# Episode 7392 | Reward 12.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2446352
# Episode 7393 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2446659
# Episode 7394 | Reward 28.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2447020
# Episode 7395 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2447350
# Episode 7396 | Reward 11.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2447615
# Episode 7397 | Reward 26.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2448025
# Episode 7398 | Reward 153.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2448565
# Episode 7399 | Reward 14.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2448886
# Episode 7400 | Reward 12.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2449164
# Episode 7401 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2449471
# Episode 7402 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2449763
# Episode 7403 | Reward 37.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2450223
# Episode 7404 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2450457
# Episode 7405 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2450693
# Episode 7406 | Reward 9.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2450992
# Episode 7407 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2451299
# Episode 7408 | Reward 18.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2451656
# Episode 7409 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2451963
# Episode 7410 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2452270
# Episode 7411 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2452504
# Episode 7412 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2452740
# Episode 7413 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2452976
# Episode 7414 | Reward 271.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2453627
# Episode 7415 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2453863
# Episode 7416 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2454069
# Episode 7417 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2454377
# Episode 7418 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2454632
# Episode 7419 | Reward 9.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2454936
# Episode 7420 | Reward 2.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2455113
# Episode 7421 | Reward 6.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2455431
# Episode 7422 | Reward 6.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2455751
# Episode 7423 | Reward 242.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2456326
# Episode 7424 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2456562
# Episode 7425 | Reward 5.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2456850
# Episode 7426 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2457157
# Episode 7427 | Reward 15.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2457493
# Episode 7428 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2457729
# Episode 7429 | Reward 5.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2458013
# Episode 7430 | Reward 23.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2458472
# Episode 7431 | Reward 14.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2458793
# Episode 7432 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2459118
# Episode 7433 | Reward 18.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2459491
# Episode 7434 | Reward 18.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2459863
# Episode 7435 | Reward 12.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2460141
# Episode 7436 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2460348
# Episode 7437 | Reward 40.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2460896
# Episode 7438 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2461132
# Episode 7439 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2461338
# Episode 7440 | Reward 11.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2461742
# Episode 7441 | Reward 17.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2462210
# Episode 7442 | Reward 16.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2462633
# Episode 7443 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2462909
# Episode 7444 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2463309
# Episode 7445 | Reward 15.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2463731
# Episode 7446 | Reward 45.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2464232
# Episode 7447 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2464486
# Episode 7448 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2464762
# Episode 7449 | Reward 38.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2465166
# Episode 7450 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2465402
# Episode 7451 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2465674
# Episode 7452 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2465881
# Episode 7453 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2466206
# Episode 7454 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2466412
# Episode 7455 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2466665
# Episode 7456 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2466921
# Episode 7457 | Reward 290.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2467562
# Episode 7458 | Reward 32.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2468033
# Episode 7459 | Reward 21.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2468393
# Episode 7460 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2468716
# Episode 7461 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2468988
# Episode 7462 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2469260
# Episode 7463 | Reward 5.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2469527
# Episode 7464 | Reward 34.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2469982
# Episode 7465 | Reward 18.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2470374
# Episode 7466 | Reward 11.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2470776
# Episode 7467 | Reward 29.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2471151
# Episode 7468 | Reward 22.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2471597
# Episode 7469 | Reward 333.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2472332
# Episode 7470 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2472538
# Episode 7471 | Reward 12.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2472830
# Episode 7472 | Reward 9.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2473148
# Episode 7473 | Reward 196.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2473776
# Episode 7474 | Reward 105.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2474350
# Episode 7475 | Reward 157.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2474922
# Episode 7476 | Reward 5.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2475207
# Episode 7477 | Reward 31.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2475699
# Episode 7478 | Reward 9.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2476020
# Episode 7479 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2476292
# Episode 7480 | Reward 26.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2476754
# Episode 7481 | Reward 157.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2477325
# Episode 7482 | Reward 11.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2477588
# Episode 7483 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2477830
# Episode 7484 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2478036
# Episode 7485 | Reward 15.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2478462
# Episode 7486 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2478667
# Episode 7487 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2478892
# Episode 7488 | Reward 14.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2479248
# Episode 7489 | Reward 5.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2479518
# Episode 7490 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2479825
# Episode 7491 | Reward 14.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2480183
# Episode 7492 | Reward 5.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2480506
# Episode 7493 | Reward 26.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2480840
# Episode 7494 | Reward 188.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2481425
# Episode 7495 | Reward 12.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2481703
# Episode 7496 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2482096
# Episode 7497 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2482330
# Episode 7498 | Reward 45.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2482827
# Episode 7499 | Reward 18.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2483199
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# VIDEO SAVED: videos/episode_7500_steps_2483442.mp4 reward: 14.0
# Episode 7500 | Reward 7.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2483442
# Episode 7501 | Reward 12.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2483721
# Episode 7502 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2483928
# Episode 7503 | Reward 9.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2484253
# Episode 7504 | Reward 14.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2484610
# Episode 7505 | Reward 12.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2484889
# Episode 7506 | Reward 2.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2485066
# Episode 7507 | Reward 228.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2485620
# Episode 7508 | Reward 5.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2485889
# Episode 7509 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2486161
# Episode 7510 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2486510
# Episode 7511 | Reward 303.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2487186
# Episode 7512 | Reward 14.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2487528
# Episode 7513 | Reward 25.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2487938
# Episode 7514 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2488267
# Episode 7515 | Reward 306.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2489043
# Episode 7516 | Reward 10.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2489365
# Episode 7517 | Reward 18.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2489722
# Episode 7518 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2490029
# Episode 7519 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2490265
# Episode 7520 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2490537
# Episode 7521 | Reward 10.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2490906
# Episode 7522 | Reward 25.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2491273
# Episode 7523 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2491480
# Episode 7524 | Reward 47.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2492014
# Episode 7525 | Reward 8.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2492286
# Episode 7526 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2492623
# Episode 7527 | Reward 2.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2492800
# Episode 7528 | Reward 2.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2492976
# Episode 7529 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2493203
# Episode 7530 | Reward 5.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2493488
# Episode 7531 | Reward 148.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2493966
# Episode 7532 | Reward 158.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2494473
# Episode 7533 | Reward 7.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2494716
# Episode 7534 | Reward 5.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2495018
# Episode 7535 | Reward 18.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2495377
# Episode 7536 | Reward 9.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2495682
# Episode 7537 | Reward 32.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2496096
# Episode 7538 | Reward 14.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2496443
# Episode 7539 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2496683
# Episode 7540 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2496889
# Episode 7541 | Reward 14.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2497243
# Episode 7542 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2497453
# Episode 7543 | Reward 21.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2497894
# Episode 7544 | Reward 1.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2498042
# Episode 7545 | Reward 9.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2498359
# Episode 7546 | Reward 21.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2498760
# Episode 7547 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2499089
# Episode 7548 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2499437
# Episode 7549 | Reward 3.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2499644
# Episode 7550 | Reward 4.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2499884
# Episode 7551 | Reward 13.0 | Buffer length 300000 | Epsilon 0.100 | Steps 2500212

# %%
import os, imageio, torch, numpy as np
from collections import deque

EVAL_EPISODES = 2
EVAL_DIR = "videos"
os.makedirs(EVAL_DIR, exist_ok=True)

q_net.eval()

for ep in range(1, EVAL_EPISODES + 1):

    frames = []
    total_reward = 0.0

    obs, info = env.reset()

    prev_obs = obs
    obs, _, _, _, info = env.step(FIRE_ACTION)
    prev_obs = obs
    obs, _, _, _, info = env.step(FIRE_ACTION)

    prev_lives = info.get("lives", None)

    obs_proc = preprocess(obs, prev_obs)
    frame_stack = deque([obs_proc] * FRAME_STACK, maxlen=FRAME_STACK)
    state = np.stack(frame_stack, axis=0)

    for step in range(MAX_EPISODE_STEPS):
        frames.append(obs)

        with torch.no_grad():
            q_vals = q_net(torch.tensor(state, device=DEVICE).unsqueeze(0))
            action = torch.argmax(q_vals).item()

        prev_obs = obs
        obs, reward, done, info = step_with_skip(env, action)
        total_reward += reward

        if (not done) and ("lives" in info) and (prev_lives is not None) and (info["lives"] < prev_lives):
            prev_obs_fire = obs
            obs, reward_fire, done_fire, info_fire = step_with_skip(env, FIRE_ACTION)
            total_reward += reward_fire
            prev_obs = prev_obs_fire
            done = done_fire
            info = info_fire

        if "lives" in info:
            prev_lives = info["lives"]

        obs_proc = preprocess(obs, prev_obs)
        frame_stack.append(obs_proc)
        state = np.stack(frame_stack, axis=0)

        if done:
            break

    video_path = f"{EVAL_DIR}/eval_{ep}.mp4"
    imageio.mimsave(video_path, frames, fps=30)

    print(f"EVAL {ep}: reward = {total_reward}, steps = {step + 1}")
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# EVAL 1: reward = 14.0, steps = 386
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# EVAL 2: reward = 14.0, steps = 386

# %%
# !zip -r videos.zip videos
from google.colab import files
files.download("videos.zip")
# Out:
#   adding: videos/ (stored 0%)
#   adding: videos/episode_2100_steps_415777.mp4 (deflated 23%)
#   adding: videos/eval_1.mp4 (deflated 23%)
#   adding: videos/episode_1200_steps_188524.mp4 (deflated 28%)
#   adding: videos/episode_3000_steps_651152.mp4 (deflated 24%)
#   adding: videos/episode_3900_steps_984233.mp4 (deflated 24%)
#   adding: videos/episode_1800_steps_334526.mp4 (deflated 24%)
#   adding: videos/episode_600_steps_91742.mp4 (deflated 45%)
#   adding: videos/episode_7500_steps_2483442.mp4 (deflated 22%)
#   adding: videos/episode_7200_steps_2383664.mp4 (deflated 24%)
#   adding: videos/episode_5700_steps_1772683.mp4 (deflated 22%)
#   adding: videos/episode_4200_steps_1114291.mp4 (deflated 24%)
#   adding: videos/episode_6300_steps_2027602.mp4 (deflated 27%)
#   adding: videos/episode_4500_steps_1242784.mp4 (deflated 23%)
#   adding: videos/episode_6000_steps_1904222.mp4 (deflated 28%)
#   adding: videos/episode_900_steps_138143.mp4 (deflated 43%)
#   adding: videos/episode_1500_steps_256536.mp4 (deflated 22%)
#   adding: videos/episode_3300_steps_762618.mp4 (deflated 24%)
#   adding: videos/episode_300_steps_45956.mp4 (deflated 36%)
#   adding: videos/episode_5400_steps_1631755.mp4 (deflated 22%)
#   adding: videos/episode_2400_steps_482076.mp4 (deflated 25%)
#   adding: videos/episode_3600_steps_867943.mp4 (deflated 22%)
#   adding: videos/eval_2.mp4 (deflated 23%)
#   adding: videos/episode_5100_steps_1504754.mp4 (deflated 27%)
#   adding: videos/episode_6600_steps_2149024.mp4 (deflated 25%)
#   adding: videos/episode_2700_steps_552398.mp4 (deflated 23%)
#   adding: videos/episode_4800_steps_1380572.mp4 (deflated 26%)
#   adding: videos/episode_6900_steps_2264931.mp4 (deflated 24%)

# %%
# !zip -r models.zip models
from google.colab import files
files.download("models.zip")
# Out:
#   adding: models/ (stored 0%)
#   adding: models/qnet_latest.pt (deflated 20%)
