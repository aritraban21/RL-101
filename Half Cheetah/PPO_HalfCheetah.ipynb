# %% [markdown]
# PPO
# Half Cheetah

# %%
import os
os.environ["MUJOCO_GL"] = "egl"
os.environ["PYOPENGL_PLATFORM"] = "egl"

# %%
# !pip install gymnasium[mujoco]
# Out:
# Requirement already satisfied: gymnasium[mujoco] in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (0.0.4)
# Requirement already satisfied: mujoco>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (3.5.0)
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (2.37.2)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (26.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio>=2.14.1->gymnasium[mujoco]) (11.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.13.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (2.10.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (3.1.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (3.23.0)

# %%
import gymnasium as gym
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
import imageio
import os
from google.colab import files

# %%
def set_seed(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# %%
# Actor Critic Network (shared backbone architecture)

class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim, hidden=256):
        super().__init__()

        self.shared = nn.Sequential(
            nn.Linear(state_dim, hidden),
            nn.Tanh(),
            nn.Linear(hidden, hidden),
            nn.Tanh(),
        )

        self.mu_head = nn.Linear(hidden, action_dim)
        self.log_std = nn.Parameter(torch.ones(action_dim) * -0.5)
        self.value_head = nn.Linear(hidden, 1)

    def forward(self, x):
        z = self.shared(x)
        mu = self.mu_head(z)

        log_std = torch.clamp(self.log_std, -5, 2)
        std = torch.exp(log_std)

        value = self.value_head(z).squeeze(-1)
        return mu, std, value

    def get_action(self, state):
        mu, std, value = self.forward(state)
        dist = torch.distributions.Normal(mu, std)

        u = dist.rsample()
        action = torch.tanh(u)

        logp = dist.log_prob(u)
        logp -= torch.log(1 - action.pow(2) + 1e-6)
        logp = logp.sum(-1)

        entropy = dist.entropy().sum(-1)
        return action, logp, entropy, value

    def evaluate_actions(self, states, actions):
        mu, std, value = self.forward(states)
        dist = torch.distributions.Normal(mu, std)

        eps = 1e-6
        actions = torch.clamp(actions, -1 + eps, 1 - eps)
        u = 0.5 * torch.log((1 + actions) / (1 - actions))

        logp = dist.log_prob(u)
        logp -= torch.log(1 - actions.pow(2) + 1e-6)
        logp = logp.sum(-1)

        entropy = dist.entropy().sum(-1)
        return logp, entropy, value

    def act_deterministic(self, state):
        with torch.no_grad():
            mu, _, _ = self.forward(state)
            return torch.tanh(mu)


# Computing GAE

@torch.no_grad()
def compute_gae(rewards, dones, values, next_value, gamma=0.99, gae_lambda=0.95):
    T = rewards.shape[0]
    advantages = torch.zeros(T, device=rewards.device)

    gae = 0
    for t in reversed(range(T)):
        mask = 1.0 - dones[t]
        v_next = next_value if t == T - 1 else values[t + 1]
        delta = rewards[t] + gamma * v_next * mask - values[t]
        gae = delta + gamma * gae_lambda * mask * gae
        advantages[t] = gae

    returns = advantages + values
    return advantages.detach(), returns.detach()


# Training setup

seed = 0
set_seed(seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

env = gym.make("HalfCheetah-v5")
eval_env = gym.make("HalfCheetah-v5", render_mode="rgb_array")

os.makedirs("videos", exist_ok=True)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]

initial_lr = 3e-4
model = ActorCritic(state_dim, action_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=initial_lr)

# PPO hyperparameters
gamma = 0.99
gae_lambda = 0.95
clip_eps = 0.2
vf_coef = 0.5
ent_coef = 0.01
max_grad_norm = 0.5
ppo_epochs = 10
mini_batch_size = 64

rollout_len = 2048
total_timesteps = 2_000_000
eval_interval = 20_000

global_step = 0
state, _ = env.reset()

# PPO training loop

while global_step < total_timesteps:

    # LR Annealing
    frac = 1.0 - (global_step / total_timesteps)
    lr_now = initial_lr * frac
    for param_group in optimizer.param_groups:
        param_group["lr"] = lr_now

    states, actions, rewards, dones, values, logps = [], [], [], [], [], []
    rollout_rewards = []

    # Rollouts
    for _ in range(rollout_len):

        state_tensor = torch.tensor(state, dtype=torch.float32, device=device)
        action, logp, entropy, value = model.get_action(state_tensor)

        next_state, reward, terminated, truncated, _ = env.step(
            action.detach().cpu().numpy()
        )

        done = terminated or truncated

        states.append(state_tensor)
        actions.append(action.detach())
        rewards.append(torch.tensor(reward, dtype=torch.float32, device=device))
        dones.append(torch.tensor(float(done), dtype=torch.float32, device=device))
        values.append(value.detach())
        logps.append(logp.detach())

        rollout_rewards.append(reward)

        state = next_state
        global_step += 1

        if done:
            state, _ = env.reset()

        if global_step >= total_timesteps:
            break

    mean_rollout_reward = np.mean(rollout_rewards)

    states = torch.stack(states)
    actions = torch.stack(actions)
    rewards = torch.stack(rewards)
    dones = torch.stack(dones)
    values = torch.stack(values)
    logps_old = torch.stack(logps)

    with torch.no_grad():
        last_state_tensor = torch.tensor(state, dtype=torch.float32, device=device)
        _, _, next_value = model.forward(last_state_tensor)

    # Advantage Norm
    advantages, returns = compute_gae(
        rewards, dones, values, next_value, gamma, gae_lambda
    )

    advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

    dataset_size = states.size(0)

    # Logging metrics
    approx_kl_total = 0
    clip_frac_total = 0
    explained_var_total = 0
    update_steps = 0

    # PPO main training loop
    for _ in range(ppo_epochs):

        indices = torch.randperm(dataset_size, device=device)

        for start in range(0, dataset_size, mini_batch_size):
            end = start + mini_batch_size
            batch_idx = indices[start:end]

            mb_states = states[batch_idx]
            mb_actions = actions[batch_idx]
            mb_advantages = advantages[batch_idx]
            mb_returns = returns[batch_idx]
            mb_logps_old = logps_old[batch_idx]
            mb_values_old = values[batch_idx]

            logps_new, entropy, values_new = model.evaluate_actions(
                mb_states, mb_actions
            )

            ratio = torch.exp(logps_new - mb_logps_old)

            surr1 = ratio * mb_advantages
            surr2 = torch.clamp(ratio, 1 - clip_eps, 1 + clip_eps) * mb_advantages      # PPO clipping

            policy_loss = -torch.min(surr1, surr2).mean()

            value_clipped = mb_values_old + torch.clamp(
                values_new - mb_values_old,
                -clip_eps,
                clip_eps,
            )

            # Value function clipping
            v_loss1 = (values_new - mb_returns).pow(2)
            v_loss2 = (value_clipped - mb_returns).pow(2)
            value_loss = 0.5 * torch.max(v_loss1, v_loss2).mean()

            entropy_loss = entropy.mean()

            # PPO Loss
            loss = policy_loss + vf_coef * value_loss - ent_coef * entropy_loss

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)      # Gradient clipping
            optimizer.step()

            # Logging stats
            approx_kl = (mb_logps_old - logps_new).mean().item()
            clip_frac = ((ratio - 1.0).abs() > clip_eps).float().mean().item()
            explained_var = 1 - torch.var(mb_returns - values_new) / (
                torch.var(mb_returns) + 1e-8
            )

            approx_kl_total += approx_kl
            clip_frac_total += clip_frac
            explained_var_total += explained_var.item()
            update_steps += 1

    print(
        f"Step: {global_step} | "
        f"LR: {lr_now:.6f} | "
        f"Reward: {mean_rollout_reward:.2f} | "
        f"KL: {approx_kl_total/update_steps:.5f} | "
        f"ClipFrac: {clip_frac_total/update_steps:.3f} | "
        f"ExplVar: {explained_var_total/update_steps:.3f}"
    )

    # Evaluation
    if global_step % eval_interval < rollout_len:

        s, _ = eval_env.reset()
        done = False
        ep_return = 0
        frames = []

        while not done:
            s_tensor = torch.tensor(s, dtype=torch.float32, device=device)
            action = model.act_deterministic(s_tensor)

            # Determininstic evaluation
            s, r, terminated, truncated, _ = eval_env.step(
                action.cpu().numpy()
            )
            done = terminated or truncated
            ep_return += r

            frame = eval_env.render()
            if frame is not None:
                frames.append(frame)

        print(f"[Eval @ {global_step}] Return: {ep_return:.2f}")

        video_path = f"videos/ppo_halfcheetah_eval_{global_step}.mp4"
        imageio.mimsave(video_path, frames, fps=30)
        print(f"Saved video: {video_path}")

env.close()
eval_env.close()
# Out:
# Device: cuda
# Step: 2048 | LR: 0.000300 | Reward: -0.22 | KL: 0.07874 | ClipFrac: 0.551 | ExplVar: 0.026
# Step: 4096 | LR: 0.000300 | Reward: -0.07 | KL: 0.07960 | ClipFrac: 0.543 | ExplVar: 0.096
# Step: 6144 | LR: 0.000299 | Reward: -0.12 | KL: 0.05712 | ClipFrac: 0.496 | ExplVar: 0.169
# Step: 8192 | LR: 0.000299 | Reward: -0.09 | KL: 0.05150 | ClipFrac: 0.453 | ExplVar: 0.233
# Step: 10240 | LR: 0.000299 | Reward: -0.07 | KL: 0.04710 | ClipFrac: 0.466 | ExplVar: 0.273
# Step: 12288 | LR: 0.000298 | Reward: 0.05 | KL: 0.04600 | ClipFrac: 0.435 | ExplVar: 0.297
# Step: 14336 | LR: 0.000298 | Reward: -0.02 | KL: 0.03612 | ClipFrac: 0.416 | ExplVar: 0.310
# Step: 16384 | LR: 0.000298 | Reward: 0.01 | KL: 0.04392 | ClipFrac: 0.415 | ExplVar: 0.368
# Step: 18432 | LR: 0.000298 | Reward: -0.02 | KL: 0.03709 | ClipFrac: 0.413 | ExplVar: 0.383
# Step: 20480 | LR: 0.000297 | Reward: -0.06 | KL: 0.03929 | ClipFrac: 0.399 | ExplVar: 0.374
# [Eval @ 20480] Return: 1027.99
# Saved video: videos/ppo_halfcheetah_eval_20480.mp4
# Step: 22528 | LR: 0.000297 | Reward: -0.04 | KL: 0.03437 | ClipFrac: 0.408 | ExplVar: 0.426
# Step: 24576 | LR: 0.000297 | Reward: -0.08 | KL: 0.05746 | ClipFrac: 0.451 | ExplVar: 0.530
# Step: 26624 | LR: 0.000296 | Reward: 0.02 | KL: 0.03520 | ClipFrac: 0.395 | ExplVar: 0.538
# Step: 28672 | LR: 0.000296 | Reward: -0.07 | KL: 0.03904 | ClipFrac: 0.416 | ExplVar: 0.508
# Step: 30720 | LR: 0.000296 | Reward: -0.01 | KL: 0.03586 | ClipFrac: 0.416 | ExplVar: 0.576
# Step: 32768 | LR: 0.000295 | Reward: -0.03 | KL: 0.05322 | ClipFrac: 0.435 | ExplVar: 0.627
# Step: 34816 | LR: 0.000295 | Reward: 0.02 | KL: 0.03736 | ClipFrac: 0.390 | ExplVar: 0.577
# Step: 36864 | LR: 0.000295 | Reward: -0.00 | KL: 0.03571 | ClipFrac: 0.419 | ExplVar: 0.531
# Step: 38912 | LR: 0.000294 | Reward: 0.02 | KL: 0.04978 | ClipFrac: 0.438 | ExplVar: 0.659
# Step: 40960 | LR: 0.000294 | Reward: -0.01 | KL: 0.03438 | ClipFrac: 0.418 | ExplVar: 0.624
# [Eval @ 40960] Return: 899.60
# Saved video: videos/ppo_halfcheetah_eval_40960.mp4
# Step: 43008 | LR: 0.000294 | Reward: 0.05 | KL: 0.03401 | ClipFrac: 0.411 | ExplVar: 0.649
# Step: 45056 | LR: 0.000294 | Reward: -0.04 | KL: 0.03391 | ClipFrac: 0.400 | ExplVar: 0.540
# Step: 47104 | LR: 0.000293 | Reward: 0.01 | KL: 0.03366 | ClipFrac: 0.421 | ExplVar: 0.564
# Step: 49152 | LR: 0.000293 | Reward: 0.04 | KL: 0.04648 | ClipFrac: 0.460 | ExplVar: 0.516
# Step: 51200 | LR: 0.000293 | Reward: 0.14 | KL: 0.04101 | ClipFrac: 0.444 | ExplVar: 0.602
# Step: 53248 | LR: 0.000292 | Reward: 0.06 | KL: 0.04878 | ClipFrac: 0.447 | ExplVar: 0.537
# Step: 55296 | LR: 0.000292 | Reward: 0.00 | KL: 0.04692 | ClipFrac: 0.418 | ExplVar: 0.571
# Step: 57344 | LR: 0.000292 | Reward: -0.10 | KL: 0.05909 | ClipFrac: 0.484 | ExplVar: 0.578
# Step: 59392 | LR: 0.000291 | Reward: 0.05 | KL: 0.03480 | ClipFrac: 0.395 | ExplVar: 0.482
# Step: 61440 | LR: 0.000291 | Reward: 0.15 | KL: 0.03117 | ClipFrac: 0.394 | ExplVar: 0.585
# [Eval @ 61440] Return: 214.79
# Saved video: videos/ppo_halfcheetah_eval_61440.mp4
# Step: 63488 | LR: 0.000291 | Reward: 0.10 | KL: 0.02967 | ClipFrac: 0.394 | ExplVar: 0.410
# Step: 65536 | LR: 0.000290 | Reward: 0.17 | KL: 0.03684 | ClipFrac: 0.403 | ExplVar: 0.552
# Step: 67584 | LR: 0.000290 | Reward: 0.08 | KL: 0.04966 | ClipFrac: 0.436 | ExplVar: 0.672
# Step: 69632 | LR: 0.000290 | Reward: 0.07 | KL: 0.04203 | ClipFrac: 0.434 | ExplVar: 0.611
# Step: 71680 | LR: 0.000290 | Reward: 0.20 | KL: 0.05943 | ClipFrac: 0.496 | ExplVar: 0.558
# Step: 73728 | LR: 0.000289 | Reward: 0.28 | KL: 0.03884 | ClipFrac: 0.452 | ExplVar: 0.549
# Step: 75776 | LR: 0.000289 | Reward: 0.23 | KL: 0.04121 | ClipFrac: 0.418 | ExplVar: 0.515
# Step: 77824 | LR: 0.000289 | Reward: 0.16 | KL: 0.06144 | ClipFrac: 0.487 | ExplVar: 0.698
# Step: 79872 | LR: 0.000288 | Reward: 0.21 | KL: 0.03154 | ClipFrac: 0.391 | ExplVar: 0.639
# Step: 81920 | LR: 0.000288 | Reward: 0.32 | KL: 0.02892 | ClipFrac: 0.391 | ExplVar: 0.599
# [Eval @ 81920] Return: 571.26
# Saved video: videos/ppo_halfcheetah_eval_81920.mp4
# Step: 83968 | LR: 0.000288 | Reward: 0.35 | KL: 0.05679 | ClipFrac: 0.524 | ExplVar: 0.646
# Step: 86016 | LR: 0.000287 | Reward: 0.35 | KL: 0.03248 | ClipFrac: 0.427 | ExplVar: 0.583
# Step: 88064 | LR: 0.000287 | Reward: 0.44 | KL: 0.03999 | ClipFrac: 0.472 | ExplVar: 0.578
# Step: 90112 | LR: 0.000287 | Reward: 0.44 | KL: 0.02981 | ClipFrac: 0.425 | ExplVar: 0.445
# Step: 92160 | LR: 0.000286 | Reward: 0.41 | KL: 0.04493 | ClipFrac: 0.459 | ExplVar: 0.549
# Step: 94208 | LR: 0.000286 | Reward: 0.43 | KL: 0.03762 | ClipFrac: 0.432 | ExplVar: 0.514
# Step: 96256 | LR: 0.000286 | Reward: 0.41 | KL: 0.06536 | ClipFrac: 0.552 | ExplVar: 0.485
# Step: 98304 | LR: 0.000286 | Reward: 0.44 | KL: 0.05013 | ClipFrac: 0.457 | ExplVar: 0.498
# Step: 100352 | LR: 0.000285 | Reward: 0.42 | KL: 0.03374 | ClipFrac: 0.401 | ExplVar: 0.463
# [Eval @ 100352] Return: 1209.43
# Saved video: videos/ppo_halfcheetah_eval_100352.mp4
# Step: 102400 | LR: 0.000285 | Reward: 0.42 | KL: 0.05076 | ClipFrac: 0.470 | ExplVar: 0.399
# Step: 104448 | LR: 0.000285 | Reward: 0.52 | KL: 0.05555 | ClipFrac: 0.500 | ExplVar: 0.505
# Step: 106496 | LR: 0.000284 | Reward: 0.59 | KL: 0.06376 | ClipFrac: 0.523 | ExplVar: 0.526
# Step: 108544 | LR: 0.000284 | Reward: 0.55 | KL: 0.06632 | ClipFrac: 0.518 | ExplVar: 0.531
# Step: 110592 | LR: 0.000284 | Reward: 0.08 | KL: 0.05888 | ClipFrac: 0.510 | ExplVar: 0.736
# Step: 112640 | LR: 0.000283 | Reward: 0.59 | KL: 0.04574 | ClipFrac: 0.455 | ExplVar: 0.507
# Step: 114688 | LR: 0.000283 | Reward: 0.49 | KL: 0.03871 | ClipFrac: 0.401 | ExplVar: 0.521
# Step: 116736 | LR: 0.000283 | Reward: 0.65 | KL: 0.04154 | ClipFrac: 0.468 | ExplVar: 0.557
# Step: 118784 | LR: 0.000282 | Reward: 0.48 | KL: 0.02983 | ClipFrac: 0.368 | ExplVar: 0.491
# Step: 120832 | LR: 0.000282 | Reward: 0.66 | KL: 0.04442 | ClipFrac: 0.467 | ExplVar: 0.476
# [Eval @ 120832] Return: 1243.62
# Saved video: videos/ppo_halfcheetah_eval_120832.mp4
# Step: 122880 | LR: 0.000282 | Reward: 0.53 | KL: 0.03702 | ClipFrac: 0.443 | ExplVar: 0.621
# Step: 124928 | LR: 0.000282 | Reward: 0.55 | KL: 0.07022 | ClipFrac: 0.526 | ExplVar: 0.638
# Step: 126976 | LR: 0.000281 | Reward: 0.54 | KL: 0.04596 | ClipFrac: 0.454 | ExplVar: 0.582
# Step: 129024 | LR: 0.000281 | Reward: 0.69 | KL: 0.04781 | ClipFrac: 0.471 | ExplVar: 0.522
# Step: 131072 | LR: 0.000281 | Reward: 0.46 | KL: 0.04102 | ClipFrac: 0.400 | ExplVar: 0.663
# Step: 133120 | LR: 0.000280 | Reward: 0.62 | KL: 0.03142 | ClipFrac: 0.364 | ExplVar: 0.535
# Step: 135168 | LR: 0.000280 | Reward: 0.68 | KL: 0.05667 | ClipFrac: 0.473 | ExplVar: 0.393
# Step: 137216 | LR: 0.000280 | Reward: 0.25 | KL: 0.09252 | ClipFrac: 0.548 | ExplVar: 0.804
# Step: 139264 | LR: 0.000279 | Reward: 0.37 | KL: 0.07479 | ClipFrac: 0.527 | ExplVar: 0.805
# Step: 141312 | LR: 0.000279 | Reward: 0.66 | KL: 0.03590 | ClipFrac: 0.445 | ExplVar: 0.322
# [Eval @ 141312] Return: 1204.65
# Saved video: videos/ppo_halfcheetah_eval_141312.mp4
# Step: 143360 | LR: 0.000279 | Reward: 0.64 | KL: 0.05695 | ClipFrac: 0.468 | ExplVar: 0.718
# Step: 145408 | LR: 0.000278 | Reward: 0.76 | KL: 0.03745 | ClipFrac: 0.423 | ExplVar: 0.481
# Step: 147456 | LR: 0.000278 | Reward: 0.65 | KL: 0.03176 | ClipFrac: 0.428 | ExplVar: 0.383
# Step: 149504 | LR: 0.000278 | Reward: 0.75 | KL: 0.03808 | ClipFrac: 0.423 | ExplVar: 0.432
# Step: 151552 | LR: 0.000278 | Reward: 0.44 | KL: 0.05157 | ClipFrac: 0.446 | ExplVar: 0.804
# Step: 153600 | LR: 0.000277 | Reward: 0.77 | KL: 0.05737 | ClipFrac: 0.501 | ExplVar: 0.365
# Step: 155648 | LR: 0.000277 | Reward: 0.73 | KL: 0.04833 | ClipFrac: 0.461 | ExplVar: 0.337
# Step: 157696 | LR: 0.000277 | Reward: 0.58 | KL: 0.03382 | ClipFrac: 0.376 | ExplVar: 0.385
# Step: 159744 | LR: 0.000276 | Reward: 0.73 | KL: 0.03541 | ClipFrac: 0.426 | ExplVar: 0.312
# Step: 161792 | LR: 0.000276 | Reward: 0.83 | KL: 0.04383 | ClipFrac: 0.487 | ExplVar: 0.317
# [Eval @ 161792] Return: 1204.85
# Saved video: videos/ppo_halfcheetah_eval_161792.mp4
# Step: 163840 | LR: 0.000276 | Reward: 0.71 | KL: 0.03626 | ClipFrac: 0.397 | ExplVar: 0.357
# Step: 165888 | LR: 0.000275 | Reward: 0.77 | KL: 0.05146 | ClipFrac: 0.480 | ExplVar: 0.338
# Step: 167936 | LR: 0.000275 | Reward: 0.78 | KL: 0.06283 | ClipFrac: 0.499 | ExplVar: 0.353
# Step: 169984 | LR: 0.000275 | Reward: 0.61 | KL: 0.04100 | ClipFrac: 0.391 | ExplVar: 0.686
# Step: 172032 | LR: 0.000275 | Reward: 0.79 | KL: 0.04589 | ClipFrac: 0.467 | ExplVar: 0.455
# Step: 174080 | LR: 0.000274 | Reward: 0.90 | KL: 0.03926 | ClipFrac: 0.476 | ExplVar: 0.338
# Step: 176128 | LR: 0.000274 | Reward: 0.91 | KL: 0.05614 | ClipFrac: 0.497 | ExplVar: 0.338
# Step: 178176 | LR: 0.000274 | Reward: 0.90 | KL: 0.04822 | ClipFrac: 0.481 | ExplVar: 0.241
# Step: 180224 | LR: 0.000273 | Reward: 0.84 | KL: 0.04576 | ClipFrac: 0.457 | ExplVar: 0.380
# [Eval @ 180224] Return: 1472.75
# Saved video: videos/ppo_halfcheetah_eval_180224.mp4
# Step: 182272 | LR: 0.000273 | Reward: 0.89 | KL: 0.04696 | ClipFrac: 0.436 | ExplVar: 0.397
# Step: 184320 | LR: 0.000273 | Reward: 0.92 | KL: 0.05369 | ClipFrac: 0.525 | ExplVar: 0.327
# Step: 186368 | LR: 0.000272 | Reward: 0.89 | KL: 0.03887 | ClipFrac: 0.456 | ExplVar: 0.317
# Step: 188416 | LR: 0.000272 | Reward: 0.86 | KL: 0.03660 | ClipFrac: 0.421 | ExplVar: 0.444
# Step: 190464 | LR: 0.000272 | Reward: 0.84 | KL: 0.04635 | ClipFrac: 0.416 | ExplVar: 0.379
# Step: 192512 | LR: 0.000271 | Reward: 0.94 | KL: 0.04081 | ClipFrac: 0.432 | ExplVar: 0.352
# Step: 194560 | LR: 0.000271 | Reward: 0.86 | KL: 0.05088 | ClipFrac: 0.447 | ExplVar: 0.377
# Step: 196608 | LR: 0.000271 | Reward: 0.91 | KL: 0.04804 | ClipFrac: 0.476 | ExplVar: 0.334
# Step: 198656 | LR: 0.000271 | Reward: 0.90 | KL: 0.03916 | ClipFrac: 0.423 | ExplVar: 0.318
# Step: 200704 | LR: 0.000270 | Reward: 0.57 | KL: 0.06507 | ClipFrac: 0.472 | ExplVar: 0.781
# [Eval @ 200704] Return: 1289.64
# Saved video: videos/ppo_halfcheetah_eval_200704.mp4
# Step: 202752 | LR: 0.000270 | Reward: 0.93 | KL: 0.04764 | ClipFrac: 0.455 | ExplVar: 0.343
# Step: 204800 | LR: 0.000270 | Reward: 0.98 | KL: 0.05688 | ClipFrac: 0.487 | ExplVar: 0.309
# Step: 206848 | LR: 0.000269 | Reward: 1.01 | KL: 0.05468 | ClipFrac: 0.538 | ExplVar: 0.259
# Step: 208896 | LR: 0.000269 | Reward: 0.99 | KL: 0.06068 | ClipFrac: 0.517 | ExplVar: 0.248
# Step: 210944 | LR: 0.000269 | Reward: 0.95 | KL: 0.03070 | ClipFrac: 0.410 | ExplVar: 0.321
# Step: 212992 | LR: 0.000268 | Reward: 0.37 | KL: 0.10997 | ClipFrac: 0.577 | ExplVar: 0.838
# Step: 215040 | LR: 0.000268 | Reward: 0.93 | KL: 0.03145 | ClipFrac: 0.385 | ExplVar: 0.349
# Step: 217088 | LR: 0.000268 | Reward: 0.94 | KL: 0.02932 | ClipFrac: 0.370 | ExplVar: 0.450
# Step: 219136 | LR: 0.000267 | Reward: 1.02 | KL: 0.04724 | ClipFrac: 0.491 | ExplVar: 0.291
# Step: 221184 | LR: 0.000267 | Reward: 1.00 | KL: 0.04740 | ClipFrac: 0.482 | ExplVar: 0.218
# [Eval @ 221184] Return: 1533.68
# Saved video: videos/ppo_halfcheetah_eval_221184.mp4
# Step: 223232 | LR: 0.000267 | Reward: 0.89 | KL: 0.07755 | ClipFrac: 0.495 | ExplVar: 0.794
# Step: 225280 | LR: 0.000267 | Reward: 1.06 | KL: 0.05115 | ClipFrac: 0.490 | ExplVar: 0.217
# Step: 227328 | LR: 0.000266 | Reward: 0.96 | KL: 0.03182 | ClipFrac: 0.422 | ExplVar: 0.388
# Step: 229376 | LR: 0.000266 | Reward: 0.91 | KL: 0.04043 | ClipFrac: 0.431 | ExplVar: 0.262
# Step: 231424 | LR: 0.000266 | Reward: 0.98 | KL: 0.04510 | ClipFrac: 0.424 | ExplVar: 0.296
# Step: 233472 | LR: 0.000265 | Reward: 1.03 | KL: 0.04487 | ClipFrac: 0.475 | ExplVar: 0.277
# Step: 235520 | LR: 0.000265 | Reward: 1.02 | KL: 0.03966 | ClipFrac: 0.476 | ExplVar: 0.271
# Step: 237568 | LR: 0.000265 | Reward: 0.98 | KL: 0.04654 | ClipFrac: 0.450 | ExplVar: 0.347
# Step: 239616 | LR: 0.000264 | Reward: 0.76 | KL: 0.06715 | ClipFrac: 0.462 | ExplVar: 0.804
# Step: 241664 | LR: 0.000264 | Reward: 0.60 | KL: 0.06604 | ClipFrac: 0.455 | ExplVar: 0.832
# [Eval @ 241664] Return: 1536.66
# Saved video: videos/ppo_halfcheetah_eval_241664.mp4
# Step: 243712 | LR: 0.000264 | Reward: 0.28 | KL: 0.09666 | ClipFrac: 0.526 | ExplVar: 0.865
# Step: 245760 | LR: 0.000263 | Reward: 0.85 | KL: 0.05151 | ClipFrac: 0.448 | ExplVar: 0.834
# Step: 247808 | LR: 0.000263 | Reward: 0.53 | KL: 0.13078 | ClipFrac: 0.581 | ExplVar: 0.877
# Step: 249856 | LR: 0.000263 | Reward: 0.79 | KL: 0.05065 | ClipFrac: 0.396 | ExplVar: 0.820
# Step: 251904 | LR: 0.000263 | Reward: 0.52 | KL: 0.07686 | ClipFrac: 0.470 | ExplVar: 0.884
# Step: 253952 | LR: 0.000262 | Reward: 0.94 | KL: 0.04828 | ClipFrac: 0.472 | ExplVar: 0.747
# Step: 256000 | LR: 0.000262 | Reward: 1.08 | KL: 0.03247 | ClipFrac: 0.419 | ExplVar: 0.285
# Step: 258048 | LR: 0.000262 | Reward: 0.99 | KL: 0.02965 | ClipFrac: 0.401 | ExplVar: 0.324
# Step: 260096 | LR: 0.000261 | Reward: 1.14 | KL: 0.04706 | ClipFrac: 0.429 | ExplVar: 0.323
# [Eval @ 260096] Return: 1379.52
# Saved video: videos/ppo_halfcheetah_eval_260096.mp4
# Step: 262144 | LR: 0.000261 | Reward: 0.40 | KL: 0.11408 | ClipFrac: 0.594 | ExplVar: 0.919
# Step: 264192 | LR: 0.000261 | Reward: 1.08 | KL: 0.04735 | ClipFrac: 0.444 | ExplVar: 0.262
# Step: 266240 | LR: 0.000260 | Reward: 1.05 | KL: 0.03291 | ClipFrac: 0.427 | ExplVar: 0.243
# Step: 268288 | LR: 0.000260 | Reward: 0.57 | KL: 0.07395 | ClipFrac: 0.501 | ExplVar: 0.909
# Step: 270336 | LR: 0.000260 | Reward: 1.09 | KL: 0.04683 | ClipFrac: 0.445 | ExplVar: 0.221
# Step: 272384 | LR: 0.000259 | Reward: 1.04 | KL: 0.03126 | ClipFrac: 0.389 | ExplVar: 0.335
# Step: 274432 | LR: 0.000259 | Reward: 0.69 | KL: 0.03935 | ClipFrac: 0.399 | ExplVar: 0.889
# Step: 276480 | LR: 0.000259 | Reward: 0.45 | KL: 0.04852 | ClipFrac: 0.423 | ExplVar: 0.908
# Step: 278528 | LR: 0.000259 | Reward: 1.10 | KL: 0.03519 | ClipFrac: 0.457 | ExplVar: 0.275
# Step: 280576 | LR: 0.000258 | Reward: 1.09 | KL: 0.05305 | ClipFrac: 0.502 | ExplVar: 0.256
# [Eval @ 280576] Return: 1461.29
# Saved video: videos/ppo_halfcheetah_eval_280576.mp4
# Step: 282624 | LR: 0.000258 | Reward: 1.12 | KL: 0.04385 | ClipFrac: 0.460 | ExplVar: 0.294
# Step: 284672 | LR: 0.000258 | Reward: 0.49 | KL: 0.07209 | ClipFrac: 0.493 | ExplVar: 0.924
# Step: 286720 | LR: 0.000257 | Reward: 1.06 | KL: 0.04756 | ClipFrac: 0.436 | ExplVar: 0.225
# Step: 288768 | LR: 0.000257 | Reward: 1.11 | KL: 0.05834 | ClipFrac: 0.506 | ExplVar: 0.275
# Step: 290816 | LR: 0.000257 | Reward: 1.08 | KL: 0.04155 | ClipFrac: 0.470 | ExplVar: 0.271
# Step: 292864 | LR: 0.000256 | Reward: 1.13 | KL: 0.04173 | ClipFrac: 0.446 | ExplVar: 0.280
# Step: 294912 | LR: 0.000256 | Reward: 1.14 | KL: 0.05774 | ClipFrac: 0.499 | ExplVar: 0.183
# Step: 296960 | LR: 0.000256 | Reward: 0.96 | KL: 0.03051 | ClipFrac: 0.367 | ExplVar: 0.341
# Step: 299008 | LR: 0.000255 | Reward: 1.08 | KL: 0.03167 | ClipFrac: 0.409 | ExplVar: 0.206
# Step: 301056 | LR: 0.000255 | Reward: 0.46 | KL: 0.06985 | ClipFrac: 0.485 | ExplVar: 0.919
# [Eval @ 301056] Return: 1480.03
# Saved video: videos/ppo_halfcheetah_eval_301056.mp4
# Step: 303104 | LR: 0.000255 | Reward: 1.04 | KL: 0.03613 | ClipFrac: 0.412 | ExplVar: 0.286
# Step: 305152 | LR: 0.000255 | Reward: 1.21 | KL: 0.04396 | ClipFrac: 0.452 | ExplVar: 0.295
# Step: 307200 | LR: 0.000254 | Reward: 0.90 | KL: 0.03941 | ClipFrac: 0.389 | ExplVar: 0.769
# Step: 309248 | LR: 0.000254 | Reward: 0.43 | KL: 0.08943 | ClipFrac: 0.554 | ExplVar: 0.925
# Step: 311296 | LR: 0.000254 | Reward: 0.71 | KL: 0.05539 | ClipFrac: 0.441 | ExplVar: 0.913
# Step: 313344 | LR: 0.000253 | Reward: 1.08 | KL: 0.03390 | ClipFrac: 0.431 | ExplVar: 0.375
# Step: 315392 | LR: 0.000253 | Reward: 1.19 | KL: 0.05004 | ClipFrac: 0.468 | ExplVar: 0.232
# Step: 317440 | LR: 0.000253 | Reward: 1.05 | KL: 0.02762 | ClipFrac: 0.337 | ExplVar: 0.352
# Step: 319488 | LR: 0.000252 | Reward: 1.02 | KL: 0.04678 | ClipFrac: 0.425 | ExplVar: 0.302
# Step: 321536 | LR: 0.000252 | Reward: 1.10 | KL: 0.03690 | ClipFrac: 0.389 | ExplVar: 0.324
# [Eval @ 321536] Return: 1404.06
# Saved video: videos/ppo_halfcheetah_eval_321536.mp4
# Step: 323584 | LR: 0.000252 | Reward: 0.34 | KL: 0.07093 | ClipFrac: 0.494 | ExplVar: 0.940
# Step: 325632 | LR: 0.000251 | Reward: 1.01 | KL: 0.03472 | ClipFrac: 0.367 | ExplVar: 0.409
# Step: 327680 | LR: 0.000251 | Reward: 0.87 | KL: 0.04653 | ClipFrac: 0.405 | ExplVar: 0.870
# Step: 329728 | LR: 0.000251 | Reward: 0.93 | KL: 0.03460 | ClipFrac: 0.368 | ExplVar: 0.834
# Step: 331776 | LR: 0.000251 | Reward: 0.85 | KL: 0.04214 | ClipFrac: 0.430 | ExplVar: 0.896
# Step: 333824 | LR: 0.000250 | Reward: 0.66 | KL: 0.09987 | ClipFrac: 0.534 | ExplVar: 0.936
# Step: 335872 | LR: 0.000250 | Reward: 0.46 | KL: 0.04751 | ClipFrac: 0.402 | ExplVar: 0.926
# Step: 337920 | LR: 0.000250 | Reward: 0.34 | KL: 0.08680 | ClipFrac: 0.530 | ExplVar: 0.948
# Step: 339968 | LR: 0.000249 | Reward: 0.65 | KL: 0.05546 | ClipFrac: 0.420 | ExplVar: 0.937
# Step: 342016 | LR: 0.000249 | Reward: 0.43 | KL: 0.06561 | ClipFrac: 0.483 | ExplVar: 0.950
# [Eval @ 342016] Return: 970.10
# Saved video: videos/ppo_halfcheetah_eval_342016.mp4
# Step: 344064 | LR: 0.000249 | Reward: 0.46 | KL: 0.04154 | ClipFrac: 0.388 | ExplVar: 0.944
# Step: 346112 | LR: 0.000248 | Reward: 0.31 | KL: 0.05813 | ClipFrac: 0.418 | ExplVar: 0.948
# Step: 348160 | LR: 0.000248 | Reward: -0.36 | KL: 0.07681 | ClipFrac: 0.556 | ExplVar: 0.945
# Step: 350208 | LR: 0.000248 | Reward: 0.36 | KL: 0.04272 | ClipFrac: 0.422 | ExplVar: 0.953
# Step: 352256 | LR: 0.000247 | Reward: 0.24 | KL: 0.05204 | ClipFrac: 0.445 | ExplVar: 0.960
# Step: 354304 | LR: 0.000247 | Reward: 1.05 | KL: 0.02679 | ClipFrac: 0.310 | ExplVar: 0.490
# Step: 356352 | LR: 0.000247 | Reward: 0.18 | KL: 0.05459 | ClipFrac: 0.452 | ExplVar: 0.954
# Step: 358400 | LR: 0.000247 | Reward: 0.54 | KL: 0.04929 | ClipFrac: 0.435 | ExplVar: 0.956
# Step: 360448 | LR: 0.000246 | Reward: 0.69 | KL: 0.04519 | ClipFrac: 0.400 | ExplVar: 0.938
# [Eval @ 360448] Return: 1497.86
# Saved video: videos/ppo_halfcheetah_eval_360448.mp4
# Step: 362496 | LR: 0.000246 | Reward: 0.59 | KL: 0.03769 | ClipFrac: 0.373 | ExplVar: 0.947
# Step: 364544 | LR: 0.000246 | Reward: 0.75 | KL: 0.06053 | ClipFrac: 0.461 | ExplVar: 0.951
# Step: 366592 | LR: 0.000245 | Reward: 0.77 | KL: 0.05375 | ClipFrac: 0.438 | ExplVar: 0.950
# Step: 368640 | LR: 0.000245 | Reward: 1.00 | KL: 0.02672 | ClipFrac: 0.343 | ExplVar: 0.369
# Step: 370688 | LR: 0.000245 | Reward: 0.61 | KL: 0.03720 | ClipFrac: 0.390 | ExplVar: 0.927
# Step: 372736 | LR: 0.000244 | Reward: 0.16 | KL: 0.05784 | ClipFrac: 0.467 | ExplVar: 0.964
# Step: 374784 | LR: 0.000244 | Reward: 0.78 | KL: 0.03521 | ClipFrac: 0.391 | ExplVar: 0.911
# Step: 376832 | LR: 0.000244 | Reward: 1.10 | KL: 0.04560 | ClipFrac: 0.452 | ExplVar: 0.520
# Step: 378880 | LR: 0.000243 | Reward: 0.91 | KL: 0.04510 | ClipFrac: 0.406 | ExplVar: 0.928
# Step: 380928 | LR: 0.000243 | Reward: 0.68 | KL: 0.06961 | ClipFrac: 0.487 | ExplVar: 0.961
# [Eval @ 380928] Return: 1214.71
# Saved video: videos/ppo_halfcheetah_eval_380928.mp4
# Step: 382976 | LR: 0.000243 | Reward: 1.04 | KL: 0.03660 | ClipFrac: 0.379 | ExplVar: 0.505
# Step: 385024 | LR: 0.000243 | Reward: 1.16 | KL: 0.03822 | ClipFrac: 0.407 | ExplVar: 0.308
# Step: 387072 | LR: 0.000242 | Reward: 1.10 | KL: 0.04153 | ClipFrac: 0.440 | ExplVar: 0.357
# Step: 389120 | LR: 0.000242 | Reward: 1.05 | KL: 0.04491 | ClipFrac: 0.419 | ExplVar: 0.890
# Step: 391168 | LR: 0.000242 | Reward: 0.47 | KL: 0.03824 | ClipFrac: 0.400 | ExplVar: 0.948
# Step: 393216 | LR: 0.000241 | Reward: 1.14 | KL: 0.03211 | ClipFrac: 0.406 | ExplVar: 0.352
# Step: 395264 | LR: 0.000241 | Reward: 1.17 | KL: 0.04435 | ClipFrac: 0.417 | ExplVar: 0.402
# Step: 397312 | LR: 0.000241 | Reward: 0.55 | KL: 0.07570 | ClipFrac: 0.524 | ExplVar: 0.965
# Step: 399360 | LR: 0.000240 | Reward: 1.27 | KL: 0.03980 | ClipFrac: 0.439 | ExplVar: 0.241
# Step: 401408 | LR: 0.000240 | Reward: 1.14 | KL: 0.03151 | ClipFrac: 0.373 | ExplVar: 0.367
# [Eval @ 401408] Return: -230.89
# Saved video: videos/ppo_halfcheetah_eval_401408.mp4
# Step: 403456 | LR: 0.000240 | Reward: 0.74 | KL: 0.03257 | ClipFrac: 0.369 | ExplVar: 0.923
# Step: 405504 | LR: 0.000239 | Reward: 0.44 | KL: 0.04992 | ClipFrac: 0.432 | ExplVar: 0.964
# Step: 407552 | LR: 0.000239 | Reward: 1.16 | KL: 0.02991 | ClipFrac: 0.417 | ExplVar: 0.294
# Step: 409600 | LR: 0.000239 | Reward: 1.12 | KL: 0.03742 | ClipFrac: 0.423 | ExplVar: 0.340
# Step: 411648 | LR: 0.000239 | Reward: 1.18 | KL: 0.03693 | ClipFrac: 0.393 | ExplVar: 0.360
# Step: 413696 | LR: 0.000238 | Reward: 1.16 | KL: 0.04460 | ClipFrac: 0.406 | ExplVar: 0.762
# Step: 415744 | LR: 0.000238 | Reward: 0.85 | KL: 0.03949 | ClipFrac: 0.403 | ExplVar: 0.935
# Step: 417792 | LR: 0.000238 | Reward: 1.22 | KL: 0.03253 | ClipFrac: 0.402 | ExplVar: 0.408
# Step: 419840 | LR: 0.000237 | Reward: 1.19 | KL: 0.04027 | ClipFrac: 0.447 | ExplVar: 0.310
# Step: 421888 | LR: 0.000237 | Reward: 1.22 | KL: 0.05129 | ClipFrac: 0.461 | ExplVar: 0.402
# [Eval @ 421888] Return: 1569.32
# Saved video: videos/ppo_halfcheetah_eval_421888.mp4
# Step: 423936 | LR: 0.000237 | Reward: 0.76 | KL: 0.05338 | ClipFrac: 0.443 | ExplVar: 0.949
# Step: 425984 | LR: 0.000236 | Reward: 0.80 | KL: 0.02695 | ClipFrac: 0.346 | ExplVar: 0.909
# Step: 428032 | LR: 0.000236 | Reward: 1.18 | KL: 0.03778 | ClipFrac: 0.409 | ExplVar: 0.355
# Step: 430080 | LR: 0.000236 | Reward: 1.24 | KL: 0.03696 | ClipFrac: 0.397 | ExplVar: 0.402
# Step: 432128 | LR: 0.000235 | Reward: 1.23 | KL: 0.04539 | ClipFrac: 0.421 | ExplVar: 0.346
# Step: 434176 | LR: 0.000235 | Reward: 1.14 | KL: 0.03696 | ClipFrac: 0.374 | ExplVar: 0.448
# Step: 436224 | LR: 0.000235 | Reward: 1.30 | KL: 0.03794 | ClipFrac: 0.418 | ExplVar: 0.359
# Step: 438272 | LR: 0.000235 | Reward: 1.41 | KL: 0.04136 | ClipFrac: 0.461 | ExplVar: 0.283
# Step: 440320 | LR: 0.000234 | Reward: 1.17 | KL: 0.02656 | ClipFrac: 0.376 | ExplVar: 0.349
# [Eval @ 440320] Return: 1542.41
# Saved video: videos/ppo_halfcheetah_eval_440320.mp4
# Step: 442368 | LR: 0.000234 | Reward: 1.31 | KL: 0.03684 | ClipFrac: 0.402 | ExplVar: 0.394
# Step: 444416 | LR: 0.000234 | Reward: 0.70 | KL: 0.05411 | ClipFrac: 0.422 | ExplVar: 0.954
# Step: 446464 | LR: 0.000233 | Reward: 1.31 | KL: 0.03018 | ClipFrac: 0.386 | ExplVar: 0.379
# Step: 448512 | LR: 0.000233 | Reward: 0.54 | KL: 0.05566 | ClipFrac: 0.418 | ExplVar: 0.963
# Step: 450560 | LR: 0.000233 | Reward: 1.19 | KL: 0.03730 | ClipFrac: 0.424 | ExplVar: 0.362
# Step: 452608 | LR: 0.000232 | Reward: 1.35 | KL: 0.04734 | ClipFrac: 0.465 | ExplVar: 0.356
# Step: 454656 | LR: 0.000232 | Reward: 1.38 | KL: 0.03442 | ClipFrac: 0.388 | ExplVar: 0.406
# Step: 456704 | LR: 0.000232 | Reward: 1.21 | KL: 0.03550 | ClipFrac: 0.410 | ExplVar: 0.309
# Step: 458752 | LR: 0.000231 | Reward: 1.26 | KL: 0.04343 | ClipFrac: 0.422 | ExplVar: 0.375
# Step: 460800 | LR: 0.000231 | Reward: 1.20 | KL: 0.04172 | ClipFrac: 0.392 | ExplVar: 0.434
# [Eval @ 460800] Return: 1834.60
# Saved video: videos/ppo_halfcheetah_eval_460800.mp4
# Step: 462848 | LR: 0.000231 | Reward: 1.21 | KL: 0.03259 | ClipFrac: 0.391 | ExplVar: 0.404
# Step: 464896 | LR: 0.000231 | Reward: 1.36 | KL: 0.03950 | ClipFrac: 0.438 | ExplVar: 0.338
# Step: 466944 | LR: 0.000230 | Reward: 1.28 | KL: 0.03681 | ClipFrac: 0.436 | ExplVar: 0.376
# Step: 468992 | LR: 0.000230 | Reward: 1.17 | KL: 0.03429 | ClipFrac: 0.410 | ExplVar: 0.433
# Step: 471040 | LR: 0.000230 | Reward: 1.22 | KL: 0.03246 | ClipFrac: 0.378 | ExplVar: 0.362
# Step: 473088 | LR: 0.000229 | Reward: 1.28 | KL: 0.03589 | ClipFrac: 0.411 | ExplVar: 0.378
# Step: 475136 | LR: 0.000229 | Reward: 1.35 | KL: 0.03663 | ClipFrac: 0.398 | ExplVar: 0.303
# Step: 477184 | LR: 0.000229 | Reward: 1.36 | KL: 0.03003 | ClipFrac: 0.368 | ExplVar: 0.406
# Step: 479232 | LR: 0.000228 | Reward: 1.34 | KL: 0.03022 | ClipFrac: 0.380 | ExplVar: 0.356
# Step: 481280 | LR: 0.000228 | Reward: 1.27 | KL: 0.03868 | ClipFrac: 0.383 | ExplVar: 0.385
# [Eval @ 481280] Return: 1842.01
# Saved video: videos/ppo_halfcheetah_eval_481280.mp4
# Step: 483328 | LR: 0.000228 | Reward: 0.66 | KL: 0.05246 | ClipFrac: 0.467 | ExplVar: 0.961
# Step: 485376 | LR: 0.000228 | Reward: 1.36 | KL: 0.03611 | ClipFrac: 0.367 | ExplVar: 0.305
# Step: 487424 | LR: 0.000227 | Reward: 1.06 | KL: 0.03142 | ClipFrac: 0.347 | ExplVar: 0.916
# Step: 489472 | LR: 0.000227 | Reward: 0.79 | KL: 0.04798 | ClipFrac: 0.399 | ExplVar: 0.959
# Step: 491520 | LR: 0.000227 | Reward: 1.28 | KL: 0.02616 | ClipFrac: 0.359 | ExplVar: 0.467
# Step: 493568 | LR: 0.000226 | Reward: 0.28 | KL: 0.06392 | ClipFrac: 0.447 | ExplVar: 0.968
# Step: 495616 | LR: 0.000226 | Reward: 0.53 | KL: 0.03592 | ClipFrac: 0.403 | ExplVar: 0.971
# Step: 497664 | LR: 0.000226 | Reward: 1.25 | KL: 0.03234 | ClipFrac: 0.365 | ExplVar: 0.369
# Step: 499712 | LR: 0.000225 | Reward: 1.17 | KL: 0.03625 | ClipFrac: 0.362 | ExplVar: 0.842
# Step: 501760 | LR: 0.000225 | Reward: 1.20 | KL: 0.02657 | ClipFrac: 0.331 | ExplVar: 0.506
# [Eval @ 501760] Return: 1862.71
# Saved video: videos/ppo_halfcheetah_eval_501760.mp4
# Step: 503808 | LR: 0.000225 | Reward: 1.28 | KL: 0.03745 | ClipFrac: 0.368 | ExplVar: 0.384
# Step: 505856 | LR: 0.000224 | Reward: 1.32 | KL: 0.03355 | ClipFrac: 0.349 | ExplVar: 0.353
# Step: 507904 | LR: 0.000224 | Reward: 1.33 | KL: 0.03419 | ClipFrac: 0.376 | ExplVar: 0.318
# Step: 509952 | LR: 0.000224 | Reward: 1.16 | KL: 0.03782 | ClipFrac: 0.368 | ExplVar: 0.801
# Step: 512000 | LR: 0.000224 | Reward: 1.22 | KL: 0.03553 | ClipFrac: 0.379 | ExplVar: 0.393
# Step: 514048 | LR: 0.000223 | Reward: 1.16 | KL: 0.02845 | ClipFrac: 0.340 | ExplVar: 0.446
# Step: 516096 | LR: 0.000223 | Reward: 1.14 | KL: 0.04242 | ClipFrac: 0.402 | ExplVar: 0.904
# Step: 518144 | LR: 0.000223 | Reward: 1.27 | KL: 0.03082 | ClipFrac: 0.369 | ExplVar: 0.386
# Step: 520192 | LR: 0.000222 | Reward: 1.43 | KL: 0.03979 | ClipFrac: 0.401 | ExplVar: 0.359
# [Eval @ 520192] Return: 1990.35
# Saved video: videos/ppo_halfcheetah_eval_520192.mp4
# Step: 522240 | LR: 0.000222 | Reward: 1.24 | KL: 0.02315 | ClipFrac: 0.385 | ExplVar: 0.339
# Step: 524288 | LR: 0.000222 | Reward: 0.58 | KL: 0.04866 | ClipFrac: 0.422 | ExplVar: 0.963
# Step: 526336 | LR: 0.000221 | Reward: 1.36 | KL: 0.04321 | ClipFrac: 0.409 | ExplVar: 0.407
# Step: 528384 | LR: 0.000221 | Reward: 1.40 | KL: 0.03451 | ClipFrac: 0.398 | ExplVar: 0.275
# Step: 530432 | LR: 0.000221 | Reward: 1.37 | KL: 0.03499 | ClipFrac: 0.384 | ExplVar: 0.388
# Step: 532480 | LR: 0.000220 | Reward: 1.39 | KL: 0.03348 | ClipFrac: 0.356 | ExplVar: 0.409
# Step: 534528 | LR: 0.000220 | Reward: 1.36 | KL: 0.03496 | ClipFrac: 0.398 | ExplVar: 0.366
# Step: 536576 | LR: 0.000220 | Reward: 1.30 | KL: 0.02979 | ClipFrac: 0.351 | ExplVar: 0.412
# Step: 538624 | LR: 0.000220 | Reward: 1.31 | KL: 0.04310 | ClipFrac: 0.373 | ExplVar: 0.867
# Step: 540672 | LR: 0.000219 | Reward: 1.39 | KL: 0.03318 | ClipFrac: 0.388 | ExplVar: 0.321
# [Eval @ 540672] Return: 1870.75
# Saved video: videos/ppo_halfcheetah_eval_540672.mp4
# Step: 542720 | LR: 0.000219 | Reward: 1.28 | KL: 0.04210 | ClipFrac: 0.387 | ExplVar: 0.912
# Step: 544768 | LR: 0.000219 | Reward: 0.76 | KL: 0.04769 | ClipFrac: 0.409 | ExplVar: 0.966
# Step: 546816 | LR: 0.000218 | Reward: 1.25 | KL: 0.03788 | ClipFrac: 0.353 | ExplVar: 0.729
# Step: 548864 | LR: 0.000218 | Reward: 0.81 | KL: 0.04485 | ClipFrac: 0.425 | ExplVar: 0.963
# Step: 550912 | LR: 0.000218 | Reward: 0.61 | KL: 0.03627 | ClipFrac: 0.385 | ExplVar: 0.961
# Step: 552960 | LR: 0.000217 | Reward: 1.22 | KL: 0.04019 | ClipFrac: 0.348 | ExplVar: 0.827
# Step: 555008 | LR: 0.000217 | Reward: 1.29 | KL: 0.02777 | ClipFrac: 0.353 | ExplVar: 0.784
# Step: 557056 | LR: 0.000217 | Reward: 1.48 | KL: 0.03862 | ClipFrac: 0.406 | ExplVar: 0.350
# Step: 559104 | LR: 0.000216 | Reward: 1.22 | KL: 0.03638 | ClipFrac: 0.362 | ExplVar: 0.936
# Step: 561152 | LR: 0.000216 | Reward: 1.53 | KL: 0.03830 | ClipFrac: 0.458 | ExplVar: 0.281
# [Eval @ 561152] Return: 1990.65
# Saved video: videos/ppo_halfcheetah_eval_561152.mp4
# Step: 563200 | LR: 0.000216 | Reward: 1.41 | KL: 0.03103 | ClipFrac: 0.387 | ExplVar: 0.328
# Step: 565248 | LR: 0.000216 | Reward: 1.57 | KL: 0.03888 | ClipFrac: 0.406 | ExplVar: 0.321
# Step: 567296 | LR: 0.000215 | Reward: 1.58 | KL: 0.04808 | ClipFrac: 0.428 | ExplVar: 0.804
# Step: 569344 | LR: 0.000215 | Reward: 1.42 | KL: 0.02609 | ClipFrac: 0.353 | ExplVar: 0.320
# Step: 571392 | LR: 0.000215 | Reward: 1.05 | KL: 0.03315 | ClipFrac: 0.357 | ExplVar: 0.929
# Step: 573440 | LR: 0.000214 | Reward: 0.88 | KL: 0.04600 | ClipFrac: 0.411 | ExplVar: 0.971
# Step: 575488 | LR: 0.000214 | Reward: 1.42 | KL: 0.03392 | ClipFrac: 0.397 | ExplVar: 0.349
# Step: 577536 | LR: 0.000214 | Reward: 1.54 | KL: 0.03002 | ClipFrac: 0.406 | ExplVar: 0.295
# Step: 579584 | LR: 0.000213 | Reward: 1.46 | KL: 0.03330 | ClipFrac: 0.373 | ExplVar: 0.415
# Step: 581632 | LR: 0.000213 | Reward: 1.58 | KL: 0.03178 | ClipFrac: 0.382 | ExplVar: 0.332
# [Eval @ 581632] Return: 1996.66
# Saved video: videos/ppo_halfcheetah_eval_581632.mp4
# Step: 583680 | LR: 0.000213 | Reward: 1.57 | KL: 0.02748 | ClipFrac: 0.392 | ExplVar: 0.391
# Step: 585728 | LR: 0.000212 | Reward: 1.51 | KL: 0.03415 | ClipFrac: 0.381 | ExplVar: 0.252
# Step: 587776 | LR: 0.000212 | Reward: 1.18 | KL: 0.04280 | ClipFrac: 0.431 | ExplVar: 0.953
# Step: 589824 | LR: 0.000212 | Reward: 1.51 | KL: 0.03570 | ClipFrac: 0.372 | ExplVar: 0.368
# Step: 591872 | LR: 0.000212 | Reward: 1.64 | KL: 0.03158 | ClipFrac: 0.373 | ExplVar: 0.345
# Step: 593920 | LR: 0.000211 | Reward: 1.49 | KL: 0.02942 | ClipFrac: 0.375 | ExplVar: 0.310
# Step: 595968 | LR: 0.000211 | Reward: 0.86 | KL: 0.03506 | ClipFrac: 0.367 | ExplVar: 0.943
# Step: 598016 | LR: 0.000211 | Reward: 1.49 | KL: 0.03342 | ClipFrac: 0.362 | ExplVar: 0.604
# Step: 600064 | LR: 0.000210 | Reward: 1.31 | KL: 0.04716 | ClipFrac: 0.409 | ExplVar: 0.937
# [Eval @ 600064] Return: 1959.19
# Saved video: videos/ppo_halfcheetah_eval_600064.mp4
# Step: 602112 | LR: 0.000210 | Reward: 1.56 | KL: 0.03992 | ClipFrac: 0.407 | ExplVar: 0.286
# Step: 604160 | LR: 0.000210 | Reward: 1.49 | KL: 0.03720 | ClipFrac: 0.380 | ExplVar: 0.321
# Step: 606208 | LR: 0.000209 | Reward: 1.57 | KL: 0.04181 | ClipFrac: 0.418 | ExplVar: 0.319
# Step: 608256 | LR: 0.000209 | Reward: 1.44 | KL: 0.03381 | ClipFrac: 0.357 | ExplVar: 0.409
# Step: 610304 | LR: 0.000209 | Reward: 0.86 | KL: 0.05748 | ClipFrac: 0.444 | ExplVar: 0.969
# Step: 612352 | LR: 0.000208 | Reward: 1.40 | KL: 0.03040 | ClipFrac: 0.379 | ExplVar: 0.421
# Step: 614400 | LR: 0.000208 | Reward: 1.32 | KL: 0.02767 | ClipFrac: 0.329 | ExplVar: 0.881
# Step: 616448 | LR: 0.000208 | Reward: 0.51 | KL: 0.04265 | ClipFrac: 0.385 | ExplVar: 0.970
# Step: 618496 | LR: 0.000208 | Reward: 0.73 | KL: 0.03826 | ClipFrac: 0.357 | ExplVar: 0.966
# Step: 620544 | LR: 0.000207 | Reward: 1.58 | KL: 0.03129 | ClipFrac: 0.339 | ExplVar: 0.537
# [Eval @ 620544] Return: 1989.20
# Saved video: videos/ppo_halfcheetah_eval_620544.mp4
# Step: 622592 | LR: 0.000207 | Reward: 1.48 | KL: 0.03636 | ClipFrac: 0.359 | ExplVar: 0.353
# Step: 624640 | LR: 0.000207 | Reward: 1.41 | KL: 0.03376 | ClipFrac: 0.391 | ExplVar: 0.256
# Step: 626688 | LR: 0.000206 | Reward: 1.31 | KL: 0.02834 | ClipFrac: 0.373 | ExplVar: 0.403
# Step: 628736 | LR: 0.000206 | Reward: 1.46 | KL: 0.03268 | ClipFrac: 0.344 | ExplVar: 0.415
# Step: 630784 | LR: 0.000206 | Reward: 0.67 | KL: 0.04424 | ClipFrac: 0.432 | ExplVar: 0.962
# Step: 632832 | LR: 0.000205 | Reward: 0.86 | KL: 0.03260 | ClipFrac: 0.393 | ExplVar: 0.976
# Step: 634880 | LR: 0.000205 | Reward: 1.62 | KL: 0.03398 | ClipFrac: 0.389 | ExplVar: 0.318
# Step: 636928 | LR: 0.000205 | Reward: 1.21 | KL: 0.03134 | ClipFrac: 0.358 | ExplVar: 0.903
# Step: 638976 | LR: 0.000204 | Reward: 1.32 | KL: 0.03570 | ClipFrac: 0.394 | ExplVar: 0.902
# Step: 641024 | LR: 0.000204 | Reward: 1.47 | KL: 0.03305 | ClipFrac: 0.372 | ExplVar: 0.842
# [Eval @ 641024] Return: 1933.11
# Saved video: videos/ppo_halfcheetah_eval_641024.mp4
# Step: 643072 | LR: 0.000204 | Reward: 1.62 | KL: 0.04553 | ClipFrac: 0.399 | ExplVar: 0.330
# Step: 645120 | LR: 0.000204 | Reward: 0.78 | KL: 0.03866 | ClipFrac: 0.402 | ExplVar: 0.971
# Step: 647168 | LR: 0.000203 | Reward: 1.26 | KL: 0.02027 | ClipFrac: 0.291 | ExplVar: 0.931
# Step: 649216 | LR: 0.000203 | Reward: 1.57 | KL: 0.02949 | ClipFrac: 0.369 | ExplVar: 0.248
# Step: 651264 | LR: 0.000203 | Reward: 1.60 | KL: 0.03542 | ClipFrac: 0.374 | ExplVar: 0.319
# Step: 653312 | LR: 0.000202 | Reward: 1.42 | KL: 0.02884 | ClipFrac: 0.327 | ExplVar: 0.395
# Step: 655360 | LR: 0.000202 | Reward: 0.88 | KL: 0.04210 | ClipFrac: 0.396 | ExplVar: 0.966
# Step: 657408 | LR: 0.000202 | Reward: 1.43 | KL: 0.02680 | ClipFrac: 0.325 | ExplVar: 0.390
# Step: 659456 | LR: 0.000201 | Reward: 1.58 | KL: 0.03587 | ClipFrac: 0.364 | ExplVar: 0.335
# Step: 661504 | LR: 0.000201 | Reward: 1.18 | KL: 0.02030 | ClipFrac: 0.351 | ExplVar: 0.891
# [Eval @ 661504] Return: 2203.22
# Saved video: videos/ppo_halfcheetah_eval_661504.mp4
# Step: 663552 | LR: 0.000201 | Reward: 0.81 | KL: 0.05527 | ClipFrac: 0.424 | ExplVar: 0.981
# Step: 665600 | LR: 0.000200 | Reward: 1.11 | KL: 0.02749 | ClipFrac: 0.310 | ExplVar: 0.948
# Step: 667648 | LR: 0.000200 | Reward: 1.28 | KL: 0.04385 | ClipFrac: 0.430 | ExplVar: 0.969
# Step: 669696 | LR: 0.000200 | Reward: 0.37 | KL: 0.03842 | ClipFrac: 0.376 | ExplVar: 0.966
# Step: 671744 | LR: 0.000200 | Reward: 0.94 | KL: 0.02940 | ClipFrac: 0.332 | ExplVar: 0.966
# Step: 673792 | LR: 0.000199 | Reward: 1.25 | KL: 0.04737 | ClipFrac: 0.378 | ExplVar: 0.973
# Step: 675840 | LR: 0.000199 | Reward: 1.58 | KL: 0.02545 | ClipFrac: 0.303 | ExplVar: 0.328
# Step: 677888 | LR: 0.000199 | Reward: 1.56 | KL: 0.01933 | ClipFrac: 0.283 | ExplVar: 0.462
# Step: 679936 | LR: 0.000198 | Reward: 0.80 | KL: 0.04424 | ClipFrac: 0.410 | ExplVar: 0.984
# Step: 681984 | LR: 0.000198 | Reward: -0.10 | KL: 0.04187 | ClipFrac: 0.404 | ExplVar: 0.941
# [Eval @ 681984] Return: 2130.51
# Saved video: videos/ppo_halfcheetah_eval_681984.mp4
# Step: 684032 | LR: 0.000198 | Reward: 1.59 | KL: 0.02179 | ClipFrac: 0.338 | ExplVar: 0.421
# Step: 686080 | LR: 0.000197 | Reward: 0.95 | KL: 0.02275 | ClipFrac: 0.284 | ExplVar: 0.964
# Step: 688128 | LR: 0.000197 | Reward: 0.81 | KL: 0.03232 | ClipFrac: 0.349 | ExplVar: 0.970
# Step: 690176 | LR: 0.000197 | Reward: 1.76 | KL: 0.02811 | ClipFrac: 0.390 | ExplVar: 0.180
# Step: 692224 | LR: 0.000196 | Reward: 1.29 | KL: 0.02864 | ClipFrac: 0.345 | ExplVar: 0.944
# Step: 694272 | LR: 0.000196 | Reward: 1.48 | KL: 0.02506 | ClipFrac: 0.331 | ExplVar: 0.331
# Step: 696320 | LR: 0.000196 | Reward: 1.62 | KL: 0.03224 | ClipFrac: 0.333 | ExplVar: 0.290
# Step: 698368 | LR: 0.000196 | Reward: 1.58 | KL: 0.02814 | ClipFrac: 0.351 | ExplVar: 0.291
# Step: 700416 | LR: 0.000195 | Reward: 0.58 | KL: 0.03272 | ClipFrac: 0.329 | ExplVar: 0.965
# [Eval @ 700416] Return: 2101.77
# Saved video: videos/ppo_halfcheetah_eval_700416.mp4
# Step: 702464 | LR: 0.000195 | Reward: 0.27 | KL: 0.04743 | ClipFrac: 0.449 | ExplVar: 0.986
# Step: 704512 | LR: 0.000195 | Reward: 1.22 | KL: 0.02957 | ClipFrac: 0.305 | ExplVar: 0.937
# Step: 706560 | LR: 0.000194 | Reward: 1.50 | KL: 0.02208 | ClipFrac: 0.312 | ExplVar: 0.363
# Step: 708608 | LR: 0.000194 | Reward: 0.78 | KL: 0.04568 | ClipFrac: 0.402 | ExplVar: 0.975
# Step: 710656 | LR: 0.000194 | Reward: 1.58 | KL: 0.03055 | ClipFrac: 0.316 | ExplVar: 0.231
# Step: 712704 | LR: 0.000193 | Reward: 1.65 | KL: 0.02643 | ClipFrac: 0.318 | ExplVar: 0.249
# Step: 714752 | LR: 0.000193 | Reward: 1.09 | KL: 0.03501 | ClipFrac: 0.362 | ExplVar: 0.968
# Step: 716800 | LR: 0.000193 | Reward: 1.57 | KL: 0.02643 | ClipFrac: 0.342 | ExplVar: 0.216
# Step: 718848 | LR: 0.000192 | Reward: 1.63 | KL: 0.02794 | ClipFrac: 0.375 | ExplVar: 0.267
# Step: 720896 | LR: 0.000192 | Reward: 1.61 | KL: 0.02810 | ClipFrac: 0.348 | ExplVar: 0.268
# [Eval @ 720896] Return: 2016.02
# Saved video: videos/ppo_halfcheetah_eval_720896.mp4
# Step: 722944 | LR: 0.000192 | Reward: 0.64 | KL: 0.02585 | ClipFrac: 0.377 | ExplVar: 0.965
# Step: 724992 | LR: 0.000192 | Reward: 1.61 | KL: 0.03657 | ClipFrac: 0.389 | ExplVar: 0.796
# Step: 727040 | LR: 0.000191 | Reward: 1.56 | KL: 0.02680 | ClipFrac: 0.362 | ExplVar: 0.208
# Step: 729088 | LR: 0.000191 | Reward: 1.57 | KL: 0.02646 | ClipFrac: 0.304 | ExplVar: 0.464
# Step: 731136 | LR: 0.000191 | Reward: 0.78 | KL: 0.02840 | ClipFrac: 0.376 | ExplVar: 0.981
# Step: 733184 | LR: 0.000190 | Reward: 0.92 | KL: 0.03185 | ClipFrac: 0.354 | ExplVar: 0.971
# Step: 735232 | LR: 0.000190 | Reward: 1.17 | KL: 0.03393 | ClipFrac: 0.354 | ExplVar: 0.966
# Step: 737280 | LR: 0.000190 | Reward: 1.54 | KL: 0.02356 | ClipFrac: 0.313 | ExplVar: 0.319
# Step: 739328 | LR: 0.000189 | Reward: 1.50 | KL: 0.02428 | ClipFrac: 0.325 | ExplVar: 0.340
# Step: 741376 | LR: 0.000189 | Reward: 1.51 | KL: 0.02773 | ClipFrac: 0.345 | ExplVar: 0.235
# [Eval @ 741376] Return: 1963.47
# Saved video: videos/ppo_halfcheetah_eval_741376.mp4
# Step: 743424 | LR: 0.000189 | Reward: 1.52 | KL: 0.02480 | ClipFrac: 0.346 | ExplVar: 0.290
# Step: 745472 | LR: 0.000188 | Reward: 1.62 | KL: 0.03295 | ClipFrac: 0.352 | ExplVar: 0.284
# Step: 747520 | LR: 0.000188 | Reward: 1.66 | KL: 0.03314 | ClipFrac: 0.374 | ExplVar: 0.305
# Step: 749568 | LR: 0.000188 | Reward: 1.66 | KL: 0.02537 | ClipFrac: 0.353 | ExplVar: 0.237
# Step: 751616 | LR: 0.000188 | Reward: 1.63 | KL: 0.03177 | ClipFrac: 0.336 | ExplVar: 0.249
# Step: 753664 | LR: 0.000187 | Reward: 1.63 | KL: 0.02182 | ClipFrac: 0.333 | ExplVar: 0.325
# Step: 755712 | LR: 0.000187 | Reward: 1.51 | KL: 0.02339 | ClipFrac: 0.310 | ExplVar: 0.332
# Step: 757760 | LR: 0.000187 | Reward: 1.42 | KL: 0.03080 | ClipFrac: 0.349 | ExplVar: 0.311
# Step: 759808 | LR: 0.000186 | Reward: 1.64 | KL: 0.02830 | ClipFrac: 0.369 | ExplVar: 0.256
# Step: 761856 | LR: 0.000186 | Reward: 1.56 | KL: 0.03200 | ClipFrac: 0.342 | ExplVar: 0.366
# [Eval @ 761856] Return: 2124.90
# Saved video: videos/ppo_halfcheetah_eval_761856.mp4
# Step: 763904 | LR: 0.000186 | Reward: 1.38 | KL: 0.02966 | ClipFrac: 0.316 | ExplVar: 0.867
# Step: 765952 | LR: 0.000185 | Reward: 1.65 | KL: 0.03399 | ClipFrac: 0.374 | ExplVar: 0.885
# Step: 768000 | LR: 0.000185 | Reward: 1.55 | KL: 0.02982 | ClipFrac: 0.353 | ExplVar: 0.290
# Step: 770048 | LR: 0.000185 | Reward: 0.95 | KL: 0.02624 | ClipFrac: 0.341 | ExplVar: 0.963
# Step: 772096 | LR: 0.000184 | Reward: 1.59 | KL: 0.03300 | ClipFrac: 0.336 | ExplVar: 0.315
# Step: 774144 | LR: 0.000184 | Reward: 1.61 | KL: 0.03826 | ClipFrac: 0.323 | ExplVar: 0.392
# Step: 776192 | LR: 0.000184 | Reward: 1.68 | KL: 0.02807 | ClipFrac: 0.330 | ExplVar: 0.240
# Step: 778240 | LR: 0.000184 | Reward: 1.00 | KL: 0.03010 | ClipFrac: 0.328 | ExplVar: 0.970
# Step: 780288 | LR: 0.000183 | Reward: 1.69 | KL: 0.02542 | ClipFrac: 0.338 | ExplVar: 0.279
# [Eval @ 780288] Return: 2005.38
# Saved video: videos/ppo_halfcheetah_eval_780288.mp4
# Step: 782336 | LR: 0.000183 | Reward: 1.65 | KL: 0.03623 | ClipFrac: 0.353 | ExplVar: 0.250
# Step: 784384 | LR: 0.000183 | Reward: 1.65 | KL: 0.02721 | ClipFrac: 0.352 | ExplVar: 0.325
# Step: 786432 | LR: 0.000182 | Reward: 1.38 | KL: 0.04003 | ClipFrac: 0.357 | ExplVar: 0.951
# Step: 788480 | LR: 0.000182 | Reward: 1.51 | KL: 0.02733 | ClipFrac: 0.335 | ExplVar: 0.355
# Step: 790528 | LR: 0.000182 | Reward: 1.60 | KL: 0.02693 | ClipFrac: 0.339 | ExplVar: 0.263
# Step: 792576 | LR: 0.000181 | Reward: 1.59 | KL: 0.03510 | ClipFrac: 0.357 | ExplVar: 0.231
# Step: 794624 | LR: 0.000181 | Reward: 1.25 | KL: 0.02308 | ClipFrac: 0.291 | ExplVar: 0.955
# Step: 796672 | LR: 0.000181 | Reward: 1.57 | KL: 0.02798 | ClipFrac: 0.310 | ExplVar: 0.251
# Step: 798720 | LR: 0.000180 | Reward: 1.23 | KL: 0.02948 | ClipFrac: 0.367 | ExplVar: 0.944
# Step: 800768 | LR: 0.000180 | Reward: 0.88 | KL: 0.03177 | ClipFrac: 0.401 | ExplVar: 0.975
# [Eval @ 800768] Return: 1855.75
# Saved video: videos/ppo_halfcheetah_eval_800768.mp4
# Step: 802816 | LR: 0.000180 | Reward: 1.40 | KL: 0.02411 | ClipFrac: 0.316 | ExplVar: 0.953
# Step: 804864 | LR: 0.000180 | Reward: 1.59 | KL: 0.02254 | ClipFrac: 0.303 | ExplVar: 0.259
# Step: 806912 | LR: 0.000179 | Reward: 1.54 | KL: 0.02947 | ClipFrac: 0.338 | ExplVar: 0.799
# Step: 808960 | LR: 0.000179 | Reward: 1.46 | KL: 0.02236 | ClipFrac: 0.285 | ExplVar: 0.363
# Step: 811008 | LR: 0.000179 | Reward: 1.59 | KL: 0.02289 | ClipFrac: 0.337 | ExplVar: 0.223
# Step: 813056 | LR: 0.000178 | Reward: 1.53 | KL: 0.02990 | ClipFrac: 0.342 | ExplVar: 0.242
# Step: 815104 | LR: 0.000178 | Reward: 1.63 | KL: 0.01955 | ClipFrac: 0.325 | ExplVar: 0.239
# Step: 817152 | LR: 0.000178 | Reward: 1.59 | KL: 0.02084 | ClipFrac: 0.346 | ExplVar: 0.286
# Step: 819200 | LR: 0.000177 | Reward: 1.54 | KL: 0.01732 | ClipFrac: 0.319 | ExplVar: 0.333
# Step: 821248 | LR: 0.000177 | Reward: 1.41 | KL: 0.01715 | ClipFrac: 0.322 | ExplVar: 0.912
# [Eval @ 821248] Return: 1920.21
# Saved video: videos/ppo_halfcheetah_eval_821248.mp4
# Step: 823296 | LR: 0.000177 | Reward: 1.63 | KL: 0.01942 | ClipFrac: 0.329 | ExplVar: 0.298
# Step: 825344 | LR: 0.000177 | Reward: 1.60 | KL: 0.02280 | ClipFrac: 0.323 | ExplVar: 0.248
# Step: 827392 | LR: 0.000176 | Reward: 1.58 | KL: 0.02149 | ClipFrac: 0.319 | ExplVar: 0.314
# Step: 829440 | LR: 0.000176 | Reward: 1.58 | KL: 0.03347 | ClipFrac: 0.342 | ExplVar: 0.213
# Step: 831488 | LR: 0.000176 | Reward: 1.46 | KL: 0.03554 | ClipFrac: 0.374 | ExplVar: 0.929
# Step: 833536 | LR: 0.000175 | Reward: 0.83 | KL: 0.02312 | ClipFrac: 0.335 | ExplVar: 0.973
# Step: 835584 | LR: 0.000175 | Reward: 1.59 | KL: 0.01802 | ClipFrac: 0.302 | ExplVar: 0.217
# Step: 837632 | LR: 0.000175 | Reward: 1.44 | KL: 0.02573 | ClipFrac: 0.285 | ExplVar: 0.906
# Step: 839680 | LR: 0.000174 | Reward: 1.58 | KL: 0.02031 | ClipFrac: 0.308 | ExplVar: 0.418
# Step: 841728 | LR: 0.000174 | Reward: 1.62 | KL: 0.01990 | ClipFrac: 0.333 | ExplVar: 0.262
# [Eval @ 841728] Return: 2044.62
# Saved video: videos/ppo_halfcheetah_eval_841728.mp4
# Step: 843776 | LR: 0.000174 | Reward: 1.68 | KL: 0.03031 | ClipFrac: 0.318 | ExplVar: 0.280
# Step: 845824 | LR: 0.000173 | Reward: 1.02 | KL: 0.02419 | ClipFrac: 0.321 | ExplVar: 0.958
# Step: 847872 | LR: 0.000173 | Reward: 0.72 | KL: 0.02372 | ClipFrac: 0.329 | ExplVar: 0.976
# Step: 849920 | LR: 0.000173 | Reward: 0.20 | KL: 0.03216 | ClipFrac: 0.390 | ExplVar: 0.976
# Step: 851968 | LR: 0.000173 | Reward: 1.64 | KL: 0.02406 | ClipFrac: 0.297 | ExplVar: 0.861
# Step: 854016 | LR: 0.000172 | Reward: 1.47 | KL: 0.02306 | ClipFrac: 0.267 | ExplVar: 0.315
# Step: 856064 | LR: 0.000172 | Reward: 1.49 | KL: 0.02217 | ClipFrac: 0.302 | ExplVar: 0.256
# Step: 858112 | LR: 0.000172 | Reward: 1.64 | KL: 0.02146 | ClipFrac: 0.281 | ExplVar: 0.294
# Step: 860160 | LR: 0.000171 | Reward: 0.42 | KL: 0.02747 | ClipFrac: 0.332 | ExplVar: 0.979
# [Eval @ 860160] Return: 2208.12
# Saved video: videos/ppo_halfcheetah_eval_860160.mp4
# Step: 862208 | LR: 0.000171 | Reward: 1.65 | KL: 0.02069 | ClipFrac: 0.282 | ExplVar: 0.237
# Step: 864256 | LR: 0.000171 | Reward: 1.46 | KL: 0.01536 | ClipFrac: 0.260 | ExplVar: 0.424
# Step: 866304 | LR: 0.000170 | Reward: 1.56 | KL: 0.02229 | ClipFrac: 0.279 | ExplVar: 0.381
# Step: 868352 | LR: 0.000170 | Reward: 1.55 | KL: 0.01598 | ClipFrac: 0.287 | ExplVar: 0.323
# Step: 870400 | LR: 0.000170 | Reward: 1.23 | KL: 0.03188 | ClipFrac: 0.320 | ExplVar: 0.952
# Step: 872448 | LR: 0.000169 | Reward: 1.00 | KL: 0.02327 | ClipFrac: 0.334 | ExplVar: 0.980
# Step: 874496 | LR: 0.000169 | Reward: 1.13 | KL: 0.02104 | ClipFrac: 0.263 | ExplVar: 0.931
# Step: 876544 | LR: 0.000169 | Reward: 1.08 | KL: 0.02738 | ClipFrac: 0.358 | ExplVar: 0.976
# Step: 878592 | LR: 0.000169 | Reward: 1.29 | KL: 0.02430 | ClipFrac: 0.297 | ExplVar: 0.952
# Step: 880640 | LR: 0.000168 | Reward: 1.68 | KL: 0.02442 | ClipFrac: 0.297 | ExplVar: 0.231
# [Eval @ 880640] Return: 2037.47
# Saved video: videos/ppo_halfcheetah_eval_880640.mp4
# Step: 882688 | LR: 0.000168 | Reward: 0.85 | KL: 0.01995 | ClipFrac: 0.276 | ExplVar: 0.971
# Step: 884736 | LR: 0.000168 | Reward: 0.76 | KL: 0.01703 | ClipFrac: 0.301 | ExplVar: 0.976
# Step: 886784 | LR: 0.000167 | Reward: 1.68 | KL: 0.01771 | ClipFrac: 0.291 | ExplVar: 0.191
# Step: 888832 | LR: 0.000167 | Reward: 1.71 | KL: 0.01733 | ClipFrac: 0.292 | ExplVar: 0.221
# Step: 890880 | LR: 0.000167 | Reward: 1.19 | KL: 0.02168 | ClipFrac: 0.289 | ExplVar: 0.969
# Step: 892928 | LR: 0.000166 | Reward: 0.67 | KL: 0.02588 | ClipFrac: 0.319 | ExplVar: 0.967
# Step: 894976 | LR: 0.000166 | Reward: 1.27 | KL: 0.01741 | ClipFrac: 0.298 | ExplVar: 0.949
# Step: 897024 | LR: 0.000166 | Reward: 1.72 | KL: 0.02204 | ClipFrac: 0.282 | ExplVar: 0.532
# Step: 899072 | LR: 0.000165 | Reward: 1.61 | KL: 0.01664 | ClipFrac: 0.264 | ExplVar: 0.385
# Step: 901120 | LR: 0.000165 | Reward: 1.07 | KL: 0.02930 | ClipFrac: 0.308 | ExplVar: 0.975
# [Eval @ 901120] Return: 2137.22
# Saved video: videos/ppo_halfcheetah_eval_901120.mp4
# Step: 903168 | LR: 0.000165 | Reward: 1.16 | KL: 0.01987 | ClipFrac: 0.302 | ExplVar: 0.964
# Step: 905216 | LR: 0.000165 | Reward: 1.53 | KL: 0.01555 | ClipFrac: 0.270 | ExplVar: 0.347
# Step: 907264 | LR: 0.000164 | Reward: 1.63 | KL: 0.02381 | ClipFrac: 0.300 | ExplVar: 0.299
# Step: 909312 | LR: 0.000164 | Reward: 1.66 | KL: 0.02290 | ClipFrac: 0.288 | ExplVar: 0.411
# Step: 911360 | LR: 0.000164 | Reward: 1.68 | KL: 0.02178 | ClipFrac: 0.298 | ExplVar: 0.316
# Step: 913408 | LR: 0.000163 | Reward: 0.94 | KL: 0.01737 | ClipFrac: 0.292 | ExplVar: 0.974
# Step: 915456 | LR: 0.000163 | Reward: 1.44 | KL: 0.02253 | ClipFrac: 0.302 | ExplVar: 0.927
# Step: 917504 | LR: 0.000163 | Reward: 0.69 | KL: 0.01440 | ClipFrac: 0.300 | ExplVar: 0.964
# Step: 919552 | LR: 0.000162 | Reward: 1.19 | KL: 0.02046 | ClipFrac: 0.274 | ExplVar: 0.972
# Step: 921600 | LR: 0.000162 | Reward: 1.58 | KL: 0.02033 | ClipFrac: 0.310 | ExplVar: 0.325
# [Eval @ 921600] Return: 2237.50
# Saved video: videos/ppo_halfcheetah_eval_921600.mp4
# Step: 923648 | LR: 0.000162 | Reward: 1.67 | KL: 0.02411 | ClipFrac: 0.316 | ExplVar: 0.259
# Step: 925696 | LR: 0.000161 | Reward: 1.60 | KL: 0.02591 | ClipFrac: 0.319 | ExplVar: 0.347
# Step: 927744 | LR: 0.000161 | Reward: 1.62 | KL: 0.02070 | ClipFrac: 0.260 | ExplVar: 0.310
# Step: 929792 | LR: 0.000161 | Reward: 1.68 | KL: 0.02313 | ClipFrac: 0.267 | ExplVar: 0.534
# Step: 931840 | LR: 0.000161 | Reward: 1.69 | KL: 0.02256 | ClipFrac: 0.316 | ExplVar: 0.227
# Step: 933888 | LR: 0.000160 | Reward: 1.77 | KL: 0.01843 | ClipFrac: 0.265 | ExplVar: 0.228
# Step: 935936 | LR: 0.000160 | Reward: 0.96 | KL: 0.01862 | ClipFrac: 0.323 | ExplVar: 0.975
# Step: 937984 | LR: 0.000160 | Reward: 1.76 | KL: 0.01957 | ClipFrac: 0.238 | ExplVar: 0.415
# Step: 940032 | LR: 0.000159 | Reward: 1.07 | KL: 0.01396 | ClipFrac: 0.298 | ExplVar: 0.962
# [Eval @ 940032] Return: 2147.19
# Saved video: videos/ppo_halfcheetah_eval_940032.mp4
# Step: 942080 | LR: 0.000159 | Reward: 1.71 | KL: 0.01704 | ClipFrac: 0.310 | ExplVar: 0.167
# Step: 944128 | LR: 0.000159 | Reward: 1.68 | KL: 0.01843 | ClipFrac: 0.268 | ExplVar: 0.298
# Step: 946176 | LR: 0.000158 | Reward: 1.60 | KL: 0.02206 | ClipFrac: 0.271 | ExplVar: 0.245
# Step: 948224 | LR: 0.000158 | Reward: 1.56 | KL: 0.01778 | ClipFrac: 0.266 | ExplVar: 0.319
# Step: 950272 | LR: 0.000158 | Reward: 1.67 | KL: 0.01794 | ClipFrac: 0.274 | ExplVar: 0.350
# Step: 952320 | LR: 0.000157 | Reward: 1.61 | KL: 0.02705 | ClipFrac: 0.318 | ExplVar: 0.236
# Step: 954368 | LR: 0.000157 | Reward: 1.66 | KL: 0.02532 | ClipFrac: 0.295 | ExplVar: 0.310
# Step: 956416 | LR: 0.000157 | Reward: 1.79 | KL: 0.01784 | ClipFrac: 0.293 | ExplVar: 0.178
# Step: 958464 | LR: 0.000157 | Reward: 1.67 | KL: 0.01647 | ClipFrac: 0.275 | ExplVar: 0.467
# Step: 960512 | LR: 0.000156 | Reward: 1.69 | KL: 0.01641 | ClipFrac: 0.287 | ExplVar: 0.276
# [Eval @ 960512] Return: 2013.51
# Saved video: videos/ppo_halfcheetah_eval_960512.mp4
# Step: 962560 | LR: 0.000156 | Reward: 1.72 | KL: 0.01899 | ClipFrac: 0.279 | ExplVar: 0.354
# Step: 964608 | LR: 0.000156 | Reward: 1.73 | KL: 0.02168 | ClipFrac: 0.312 | ExplVar: 0.283
# Step: 966656 | LR: 0.000155 | Reward: 1.02 | KL: 0.02693 | ClipFrac: 0.303 | ExplVar: 0.969
# Step: 968704 | LR: 0.000155 | Reward: 1.63 | KL: 0.01952 | ClipFrac: 0.292 | ExplVar: 0.367
# Step: 970752 | LR: 0.000155 | Reward: 1.79 | KL: 0.01637 | ClipFrac: 0.274 | ExplVar: 0.235
# Step: 972800 | LR: 0.000154 | Reward: 1.65 | KL: 0.01610 | ClipFrac: 0.275 | ExplVar: 0.257
# Step: 974848 | LR: 0.000154 | Reward: 1.80 | KL: 0.01491 | ClipFrac: 0.258 | ExplVar: 0.223
# Step: 976896 | LR: 0.000154 | Reward: 1.86 | KL: 0.02341 | ClipFrac: 0.315 | ExplVar: 0.213
# Step: 978944 | LR: 0.000153 | Reward: 1.75 | KL: 0.02110 | ClipFrac: 0.316 | ExplVar: 0.264
# ...
# Saved video: videos/ppo_halfcheetah_eval_1681408.mp4
# Step: 1683456 | LR: 0.000048 | Reward: 1.84 | KL: 0.00241 | ClipFrac: 0.115 | ExplVar: 0.307
# Step: 1685504 | LR: 0.000047 | Reward: 1.44 | KL: 0.00173 | ClipFrac: 0.085 | ExplVar: 0.937
# Step: 1687552 | LR: 0.000047 | Reward: 1.14 | KL: -0.00022 | ClipFrac: 0.094 | ExplVar: 0.972
# Step: 1689600 | LR: 0.000047 | Reward: 0.23 | KL: 0.00692 | ClipFrac: 0.136 | ExplVar: 0.965
# Step: 1691648 | LR: 0.000047 | Reward: 1.48 | KL: -0.00184 | ClipFrac: 0.072 | ExplVar: 0.971
# Step: 1693696 | LR: 0.000046 | Reward: 1.97 | KL: 0.00211 | ClipFrac: 0.054 | ExplVar: 0.341
# Step: 1695744 | LR: 0.000046 | Reward: 1.90 | KL: 0.00244 | ClipFrac: 0.067 | ExplVar: 0.288
# Step: 1697792 | LR: 0.000046 | Reward: 1.78 | KL: 0.00464 | ClipFrac: 0.099 | ExplVar: 0.746
# Step: 1699840 | LR: 0.000045 | Reward: 1.05 | KL: -0.00061 | ClipFrac: 0.083 | ExplVar: 0.965
# Step: 1701888 | LR: 0.000045 | Reward: 1.20 | KL: 0.00408 | ClipFrac: 0.078 | ExplVar: 0.969
# [Eval @ 1701888] Return: 2349.88
# Saved video: videos/ppo_halfcheetah_eval_1701888.mp4
# Step: 1703936 | LR: 0.000045 | Reward: 1.80 | KL: 0.00993 | ClipFrac: 0.120 | ExplVar: 0.776
# Step: 1705984 | LR: 0.000044 | Reward: 1.77 | KL: 0.00623 | ClipFrac: 0.060 | ExplVar: 0.816
# Step: 1708032 | LR: 0.000044 | Reward: 1.84 | KL: 0.00328 | ClipFrac: 0.092 | ExplVar: 0.236
# Step: 1710080 | LR: 0.000044 | Reward: 1.91 | KL: 0.00604 | ClipFrac: 0.100 | ExplVar: 0.319
# Step: 1712128 | LR: 0.000043 | Reward: 1.02 | KL: 0.00410 | ClipFrac: 0.060 | ExplVar: 0.971
# Step: 1714176 | LR: 0.000043 | Reward: 1.94 | KL: 0.00289 | ClipFrac: 0.093 | ExplVar: 0.275
# Step: 1716224 | LR: 0.000043 | Reward: 1.88 | KL: 0.00203 | ClipFrac: 0.052 | ExplVar: 0.334
# Step: 1718272 | LR: 0.000043 | Reward: 1.98 | KL: 0.00506 | ClipFrac: 0.102 | ExplVar: 0.318
# Step: 1720320 | LR: 0.000042 | Reward: 1.17 | KL: 0.00546 | ClipFrac: 0.113 | ExplVar: 0.971
# [Eval @ 1720320] Return: 2598.36
# Saved video: videos/ppo_halfcheetah_eval_1720320.mp4
# Step: 1722368 | LR: 0.000042 | Reward: 1.59 | KL: 0.00002 | ClipFrac: 0.059 | ExplVar: 0.928
# Step: 1724416 | LR: 0.000042 | Reward: 1.02 | KL: 0.00289 | ClipFrac: 0.085 | ExplVar: 0.974
# Step: 1726464 | LR: 0.000041 | Reward: 1.29 | KL: -0.00184 | ClipFrac: 0.130 | ExplVar: 0.978
# Step: 1728512 | LR: 0.000041 | Reward: 1.09 | KL: 0.00447 | ClipFrac: 0.081 | ExplVar: 0.975
# Step: 1730560 | LR: 0.000041 | Reward: 1.33 | KL: 0.00373 | ClipFrac: 0.068 | ExplVar: 0.958
# Step: 1732608 | LR: 0.000040 | Reward: 1.43 | KL: 0.00293 | ClipFrac: 0.076 | ExplVar: 0.971
# Step: 1734656 | LR: 0.000040 | Reward: 1.89 | KL: -0.00414 | ClipFrac: 0.102 | ExplVar: 0.788
# Step: 1736704 | LR: 0.000040 | Reward: 1.98 | KL: 0.00772 | ClipFrac: 0.085 | ExplVar: 0.750
# Step: 1738752 | LR: 0.000039 | Reward: 1.87 | KL: 0.00513 | ClipFrac: 0.105 | ExplVar: 0.255
# Step: 1740800 | LR: 0.000039 | Reward: 1.92 | KL: 0.00556 | ClipFrac: 0.101 | ExplVar: 0.217
# [Eval @ 1740800] Return: 2530.86
# Saved video: videos/ppo_halfcheetah_eval_1740800.mp4
# Step: 1742848 | LR: 0.000039 | Reward: 1.71 | KL: 0.00163 | ClipFrac: 0.084 | ExplVar: 0.401
# Step: 1744896 | LR: 0.000039 | Reward: 1.86 | KL: 0.00265 | ClipFrac: 0.110 | ExplVar: 0.227
# Step: 1746944 | LR: 0.000038 | Reward: 0.96 | KL: 0.00631 | ClipFrac: 0.065 | ExplVar: 0.961
# Step: 1748992 | LR: 0.000038 | Reward: 1.87 | KL: 0.00575 | ClipFrac: 0.105 | ExplVar: 0.772
# Step: 1751040 | LR: 0.000038 | Reward: 1.70 | KL: 0.00715 | ClipFrac: 0.105 | ExplVar: 0.884
# Step: 1753088 | LR: 0.000037 | Reward: 1.86 | KL: 0.00435 | ClipFrac: 0.076 | ExplVar: 0.233
# Step: 1755136 | LR: 0.000037 | Reward: 0.91 | KL: 0.00552 | ClipFrac: 0.110 | ExplVar: 0.969
# Step: 1757184 | LR: 0.000037 | Reward: 1.28 | KL: 0.00900 | ClipFrac: 0.074 | ExplVar: 0.965
# Step: 1759232 | LR: 0.000036 | Reward: 1.95 | KL: 0.00004 | ClipFrac: 0.075 | ExplVar: 0.388
# Step: 1761280 | LR: 0.000036 | Reward: 1.01 | KL: 0.00254 | ClipFrac: 0.079 | ExplVar: 0.972
# [Eval @ 1761280] Return: 2364.17
# Saved video: videos/ppo_halfcheetah_eval_1761280.mp4
# Step: 1763328 | LR: 0.000036 | Reward: 1.91 | KL: 0.00165 | ClipFrac: 0.061 | ExplVar: 0.329
# Step: 1765376 | LR: 0.000036 | Reward: 1.98 | KL: 0.00711 | ClipFrac: 0.100 | ExplVar: 0.314
# Step: 1767424 | LR: 0.000035 | Reward: 1.85 | KL: 0.00197 | ClipFrac: 0.090 | ExplVar: 0.334
# Step: 1769472 | LR: 0.000035 | Reward: 1.60 | KL: 0.00527 | ClipFrac: 0.084 | ExplVar: 0.931
# Step: 1771520 | LR: 0.000035 | Reward: 1.13 | KL: 0.00160 | ClipFrac: 0.085 | ExplVar: 0.964
# Step: 1773568 | LR: 0.000034 | Reward: 1.39 | KL: 0.00141 | ClipFrac: 0.049 | ExplVar: 0.976
# Step: 1775616 | LR: 0.000034 | Reward: 1.85 | KL: -0.00017 | ClipFrac: 0.048 | ExplVar: 0.249
# Step: 1777664 | LR: 0.000034 | Reward: 1.12 | KL: 0.00698 | ClipFrac: 0.049 | ExplVar: 0.968
# Step: 1779712 | LR: 0.000033 | Reward: 1.82 | KL: 0.00365 | ClipFrac: 0.068 | ExplVar: 0.353
# Step: 1781760 | LR: 0.000033 | Reward: 1.81 | KL: -0.00003 | ClipFrac: 0.052 | ExplVar: 0.242
# [Eval @ 1781760] Return: 2491.10
# Saved video: videos/ppo_halfcheetah_eval_1781760.mp4
# Step: 1783808 | LR: 0.000033 | Reward: 1.88 | KL: 0.00208 | ClipFrac: 0.066 | ExplVar: 0.370
# Step: 1785856 | LR: 0.000032 | Reward: 1.91 | KL: 0.00491 | ClipFrac: 0.101 | ExplVar: 0.189
# Step: 1787904 | LR: 0.000032 | Reward: 1.81 | KL: 0.00306 | ClipFrac: 0.084 | ExplVar: 0.290
# Step: 1789952 | LR: 0.000032 | Reward: 1.85 | KL: 0.00215 | ClipFrac: 0.074 | ExplVar: 0.343
# Step: 1792000 | LR: 0.000032 | Reward: 1.67 | KL: 0.00132 | ClipFrac: 0.086 | ExplVar: 0.236
# Step: 1794048 | LR: 0.000031 | Reward: 1.22 | KL: 0.00379 | ClipFrac: 0.076 | ExplVar: 0.960
# Step: 1796096 | LR: 0.000031 | Reward: 1.27 | KL: 0.00110 | ClipFrac: 0.070 | ExplVar: 0.960
# Step: 1798144 | LR: 0.000031 | Reward: 1.11 | KL: 0.00537 | ClipFrac: 0.080 | ExplVar: 0.970
# Step: 1800192 | LR: 0.000030 | Reward: 1.92 | KL: 0.01190 | ClipFrac: 0.108 | ExplVar: 0.208
# [Eval @ 1800192] Return: 2369.48
# Saved video: videos/ppo_halfcheetah_eval_1800192.mp4
# Step: 1802240 | LR: 0.000030 | Reward: 1.86 | KL: 0.00291 | ClipFrac: 0.056 | ExplVar: 0.236
# Step: 1804288 | LR: 0.000030 | Reward: 1.90 | KL: 0.01062 | ClipFrac: 0.106 | ExplVar: 0.318
# Step: 1806336 | LR: 0.000029 | Reward: 1.88 | KL: 0.00076 | ClipFrac: 0.061 | ExplVar: 0.810
# Step: 1808384 | LR: 0.000029 | Reward: 1.93 | KL: -0.00235 | ClipFrac: 0.047 | ExplVar: 0.234
# Step: 1810432 | LR: 0.000029 | Reward: 1.94 | KL: 0.00246 | ClipFrac: 0.059 | ExplVar: 0.587
# Step: 1812480 | LR: 0.000028 | Reward: 1.29 | KL: -0.00066 | ClipFrac: 0.079 | ExplVar: 0.978
# Step: 1814528 | LR: 0.000028 | Reward: 1.13 | KL: 0.00435 | ClipFrac: 0.052 | ExplVar: 0.962
# Step: 1816576 | LR: 0.000028 | Reward: 1.43 | KL: -0.00326 | ClipFrac: 0.084 | ExplVar: 0.976
# Step: 1818624 | LR: 0.000028 | Reward: 1.42 | KL: -0.00361 | ClipFrac: 0.047 | ExplVar: 0.946
# Step: 1820672 | LR: 0.000027 | Reward: 1.38 | KL: -0.00465 | ClipFrac: 0.054 | ExplVar: 0.965
# [Eval @ 1820672] Return: 2429.31
# Saved video: videos/ppo_halfcheetah_eval_1820672.mp4
# Step: 1822720 | LR: 0.000027 | Reward: 1.77 | KL: 0.00160 | ClipFrac: 0.058 | ExplVar: 0.419
# Step: 1824768 | LR: 0.000027 | Reward: 1.93 | KL: -0.00141 | ClipFrac: 0.049 | ExplVar: 0.267
# Step: 1826816 | LR: 0.000026 | Reward: 1.80 | KL: -0.00224 | ClipFrac: 0.035 | ExplVar: 0.928
# Step: 1828864 | LR: 0.000026 | Reward: 1.90 | KL: 0.00163 | ClipFrac: 0.040 | ExplVar: 0.315
# Step: 1830912 | LR: 0.000026 | Reward: 1.97 | KL: 0.00143 | ClipFrac: 0.047 | ExplVar: 0.373
# Step: 1832960 | LR: 0.000025 | Reward: 1.26 | KL: 0.00298 | ClipFrac: 0.092 | ExplVar: 0.965
# Step: 1835008 | LR: 0.000025 | Reward: 1.53 | KL: 0.00557 | ClipFrac: 0.083 | ExplVar: 0.935
# Step: 1837056 | LR: 0.000025 | Reward: 1.89 | KL: 0.00003 | ClipFrac: 0.056 | ExplVar: 0.284
# Step: 1839104 | LR: 0.000024 | Reward: 1.95 | KL: 0.00031 | ClipFrac: 0.056 | ExplVar: 0.302
# Step: 1841152 | LR: 0.000024 | Reward: 1.91 | KL: -0.00144 | ClipFrac: 0.065 | ExplVar: 0.284
# [Eval @ 1841152] Return: 2359.65
# Saved video: videos/ppo_halfcheetah_eval_1841152.mp4
# Step: 1843200 | LR: 0.000024 | Reward: 1.77 | KL: 0.00000 | ClipFrac: 0.065 | ExplVar: 0.818
# Step: 1845248 | LR: 0.000024 | Reward: 1.16 | KL: 0.00393 | ClipFrac: 0.070 | ExplVar: 0.981
# Step: 1847296 | LR: 0.000023 | Reward: 1.94 | KL: -0.00130 | ClipFrac: 0.051 | ExplVar: 0.287
# Step: 1849344 | LR: 0.000023 | Reward: 1.99 | KL: 0.00273 | ClipFrac: 0.052 | ExplVar: 0.282
# Step: 1851392 | LR: 0.000023 | Reward: 1.87 | KL: 0.00335 | ClipFrac: 0.045 | ExplVar: 0.237
# Step: 1853440 | LR: 0.000022 | Reward: 1.31 | KL: 0.00160 | ClipFrac: 0.048 | ExplVar: 0.966
# Step: 1855488 | LR: 0.000022 | Reward: 1.97 | KL: 0.00050 | ClipFrac: 0.062 | ExplVar: 0.147
# Step: 1857536 | LR: 0.000022 | Reward: 1.98 | KL: 0.00352 | ClipFrac: 0.070 | ExplVar: 0.277
# Step: 1859584 | LR: 0.000021 | Reward: 2.01 | KL: 0.00021 | ClipFrac: 0.063 | ExplVar: 0.165
# Step: 1861632 | LR: 0.000021 | Reward: 1.00 | KL: 0.00141 | ClipFrac: 0.052 | ExplVar: 0.976
# [Eval @ 1861632] Return: 2438.76
# Saved video: videos/ppo_halfcheetah_eval_1861632.mp4
# Step: 1863680 | LR: 0.000021 | Reward: 2.00 | KL: -0.00003 | ClipFrac: 0.038 | ExplVar: 0.234
# Step: 1865728 | LR: 0.000020 | Reward: 1.99 | KL: 0.00358 | ClipFrac: 0.083 | ExplVar: 0.264
# Step: 1867776 | LR: 0.000020 | Reward: 1.94 | KL: -0.00115 | ClipFrac: 0.065 | ExplVar: 0.236
# Step: 1869824 | LR: 0.000020 | Reward: 1.89 | KL: 0.00230 | ClipFrac: 0.073 | ExplVar: 0.240
# Step: 1871872 | LR: 0.000020 | Reward: 1.93 | KL: 0.00509 | ClipFrac: 0.080 | ExplVar: 0.229
# Step: 1873920 | LR: 0.000019 | Reward: 1.09 | KL: -0.00031 | ClipFrac: 0.031 | ExplVar: 0.971
# Step: 1875968 | LR: 0.000019 | Reward: 1.83 | KL: 0.00608 | ClipFrac: 0.221 | ExplVar: 0.376
# Step: 1878016 | LR: 0.000019 | Reward: 1.01 | KL: 0.00132 | ClipFrac: 0.049 | ExplVar: 0.959
# Step: 1880064 | LR: 0.000018 | Reward: 2.00 | KL: 0.00605 | ClipFrac: 0.079 | ExplVar: 0.355
# [Eval @ 1880064] Return: 2488.58
# Saved video: videos/ppo_halfcheetah_eval_1880064.mp4
# Step: 1882112 | LR: 0.000018 | Reward: 1.87 | KL: 0.00408 | ClipFrac: 0.034 | ExplVar: 0.262
# Step: 1884160 | LR: 0.000018 | Reward: 1.94 | KL: -0.00022 | ClipFrac: 0.029 | ExplVar: 0.369
# Step: 1886208 | LR: 0.000017 | Reward: 1.99 | KL: 0.00435 | ClipFrac: 0.056 | ExplVar: 0.270
# Step: 1888256 | LR: 0.000017 | Reward: 1.88 | KL: 0.00111 | ClipFrac: 0.050 | ExplVar: 0.303
# Step: 1890304 | LR: 0.000017 | Reward: 1.93 | KL: 0.00034 | ClipFrac: 0.051 | ExplVar: 0.271
# Step: 1892352 | LR: 0.000016 | Reward: 1.35 | KL: -0.00088 | ClipFrac: 0.059 | ExplVar: 0.969
# Step: 1894400 | LR: 0.000016 | Reward: 1.44 | KL: 0.00268 | ClipFrac: 0.042 | ExplVar: 0.967
# Step: 1896448 | LR: 0.000016 | Reward: 1.91 | KL: 0.00051 | ClipFrac: 0.044 | ExplVar: 0.253
# Step: 1898496 | LR: 0.000016 | Reward: 2.01 | KL: -0.00078 | ClipFrac: 0.056 | ExplVar: 0.258
# Step: 1900544 | LR: 0.000015 | Reward: 1.89 | KL: 0.00366 | ClipFrac: 0.073 | ExplVar: 0.264
# [Eval @ 1900544] Return: 2560.57
# Saved video: videos/ppo_halfcheetah_eval_1900544.mp4
# Step: 1902592 | LR: 0.000015 | Reward: 1.76 | KL: 0.00045 | ClipFrac: 0.044 | ExplVar: 0.932
# Step: 1904640 | LR: 0.000015 | Reward: 1.99 | KL: 0.00254 | ClipFrac: 0.052 | ExplVar: 0.225
# Step: 1906688 | LR: 0.000014 | Reward: 1.93 | KL: 0.00085 | ClipFrac: 0.022 | ExplVar: 0.199
# Step: 1908736 | LR: 0.000014 | Reward: 1.94 | KL: 0.00320 | ClipFrac: 0.045 | ExplVar: 0.139
# Step: 1910784 | LR: 0.000014 | Reward: 1.96 | KL: 0.00060 | ClipFrac: 0.026 | ExplVar: 0.203
# Step: 1912832 | LR: 0.000013 | Reward: 1.97 | KL: -0.00141 | ClipFrac: 0.067 | ExplVar: 0.434
# Step: 1914880 | LR: 0.000013 | Reward: 1.99 | KL: 0.00224 | ClipFrac: 0.046 | ExplVar: 0.129
# Step: 1916928 | LR: 0.000013 | Reward: 1.71 | KL: 0.00403 | ClipFrac: 0.048 | ExplVar: 0.900
# Step: 1918976 | LR: 0.000012 | Reward: 1.91 | KL: -0.00029 | ClipFrac: 0.017 | ExplVar: 0.840
# Step: 1921024 | LR: 0.000012 | Reward: 2.00 | KL: -0.00125 | ClipFrac: 0.021 | ExplVar: 0.156
# [Eval @ 1921024] Return: 2405.15
# Saved video: videos/ppo_halfcheetah_eval_1921024.mp4
# Step: 1923072 | LR: 0.000012 | Reward: 2.09 | KL: -0.00109 | ClipFrac: 0.041 | ExplVar: 0.218
# Step: 1925120 | LR: 0.000012 | Reward: 2.00 | KL: 0.00867 | ClipFrac: 0.179 | ExplVar: 0.336
# Step: 1927168 | LR: 0.000011 | Reward: 1.89 | KL: -0.00147 | ClipFrac: 0.033 | ExplVar: 0.179
# Step: 1929216 | LR: 0.000011 | Reward: 2.05 | KL: 0.00117 | ClipFrac: 0.036 | ExplVar: 0.203
# Step: 1931264 | LR: 0.000011 | Reward: 2.00 | KL: -0.00205 | ClipFrac: 0.025 | ExplVar: 0.208
# Step: 1933312 | LR: 0.000010 | Reward: 1.97 | KL: -0.00001 | ClipFrac: 0.014 | ExplVar: 0.286
# Step: 1935360 | LR: 0.000010 | Reward: 2.00 | KL: 0.00133 | ClipFrac: 0.008 | ExplVar: 0.267
# Step: 1937408 | LR: 0.000010 | Reward: 1.91 | KL: 0.00035 | ClipFrac: 0.047 | ExplVar: 0.181
# Step: 1939456 | LR: 0.000009 | Reward: 1.95 | KL: -0.00361 | ClipFrac: 0.023 | ExplVar: 0.207
# Step: 1941504 | LR: 0.000009 | Reward: 1.96 | KL: -0.00145 | ClipFrac: 0.022 | ExplVar: 0.225
# [Eval @ 1941504] Return: 2510.30
# Saved video: videos/ppo_halfcheetah_eval_1941504.mp4
# Step: 1943552 | LR: 0.000009 | Reward: 1.90 | KL: 0.00209 | ClipFrac: 0.054 | ExplVar: 0.304
# Step: 1945600 | LR: 0.000008 | Reward: 1.99 | KL: 0.00271 | ClipFrac: 0.035 | ExplVar: 0.239
# Step: 1947648 | LR: 0.000008 | Reward: 1.77 | KL: 0.00183 | ClipFrac: 0.018 | ExplVar: 0.277
# Step: 1949696 | LR: 0.000008 | Reward: 2.04 | KL: -0.00206 | ClipFrac: 0.008 | ExplVar: 0.304
# Step: 1951744 | LR: 0.000008 | Reward: 1.16 | KL: -0.00406 | ClipFrac: 0.028 | ExplVar: 0.970
# Step: 1953792 | LR: 0.000007 | Reward: 2.07 | KL: -0.00283 | ClipFrac: 0.026 | ExplVar: 0.197
# Step: 1955840 | LR: 0.000007 | Reward: 2.03 | KL: -0.00170 | ClipFrac: 0.024 | ExplVar: 0.280
# Step: 1957888 | LR: 0.000007 | Reward: 1.87 | KL: -0.00081 | ClipFrac: 0.031 | ExplVar: 0.908
# Step: 1959936 | LR: 0.000006 | Reward: 1.05 | KL: 0.00208 | ClipFrac: 0.018 | ExplVar: 0.975
# Step: 1961984 | LR: 0.000006 | Reward: 2.04 | KL: 0.00025 | ClipFrac: 0.011 | ExplVar: 0.210
# [Eval @ 1961984] Return: 2451.87
# Saved video: videos/ppo_halfcheetah_eval_1961984.mp4
# Step: 1964032 | LR: 0.000006 | Reward: 2.00 | KL: -0.00123 | ClipFrac: 0.008 | ExplVar: 0.158
# Step: 1966080 | LR: 0.000005 | Reward: 2.04 | KL: -0.00034 | ClipFrac: 0.015 | ExplVar: 0.256
# Step: 1968128 | LR: 0.000005 | Reward: 1.97 | KL: 0.00166 | ClipFrac: 0.020 | ExplVar: 0.288
# Step: 1970176 | LR: 0.000005 | Reward: 2.07 | KL: -0.00352 | ClipFrac: 0.004 | ExplVar: 0.223
# Step: 1972224 | LR: 0.000004 | Reward: 1.96 | KL: -0.00080 | ClipFrac: 0.017 | ExplVar: 0.208
# Step: 1974272 | LR: 0.000004 | Reward: 2.02 | KL: -0.00139 | ClipFrac: 0.016 | ExplVar: 0.269
# Step: 1976320 | LR: 0.000004 | Reward: 2.08 | KL: -0.00242 | ClipFrac: 0.016 | ExplVar: 0.180
# Step: 1978368 | LR: 0.000004 | Reward: 1.95 | KL: -0.00159 | ClipFrac: 0.004 | ExplVar: 0.241
# Step: 1980416 | LR: 0.000003 | Reward: 1.91 | KL: -0.00445 | ClipFrac: 0.005 | ExplVar: 0.269
# [Eval @ 1980416] Return: 2550.28
# Saved video: videos/ppo_halfcheetah_eval_1980416.mp4
# Step: 1982464 | LR: 0.000003 | Reward: 1.93 | KL: -0.00237 | ClipFrac: 0.006 | ExplVar: 0.161
# Step: 1984512 | LR: 0.000003 | Reward: 1.98 | KL: -0.00031 | ClipFrac: 0.004 | ExplVar: 0.243
# Step: 1986560 | LR: 0.000002 | Reward: 2.01 | KL: -0.00073 | ClipFrac: 0.003 | ExplVar: 0.271
# Step: 1988608 | LR: 0.000002 | Reward: 1.90 | KL: -0.00231 | ClipFrac: 0.003 | ExplVar: 0.238
# Step: 1990656 | LR: 0.000002 | Reward: 1.85 | KL: -0.00169 | ClipFrac: 0.004 | ExplVar: 0.901
# Step: 1992704 | LR: 0.000001 | Reward: 2.03 | KL: -0.00378 | ClipFrac: 0.004 | ExplVar: 0.198
# Step: 1994752 | LR: 0.000001 | Reward: 2.00 | KL: -0.00062 | ClipFrac: 0.002 | ExplVar: 0.215
# Step: 1996800 | LR: 0.000001 | Reward: 1.94 | KL: -0.00351 | ClipFrac: 0.004 | ExplVar: 0.151
# Step: 1998848 | LR: 0.000000 | Reward: 2.02 | KL: -0.00454 | ClipFrac: 0.004 | ExplVar: 0.223
# Step: 2000000 | LR: 0.000000 | Reward: 1.98 | KL: -0.00347 | ClipFrac: 0.005 | ExplVar: 0.154
# [Eval @ 2000000] Return: 2480.69
# Saved video: videos/ppo_halfcheetah_eval_2000000.mp4

# %%
# !zip -r videos.zip /content/videos
# Out:
#   adding: content/videos/ (stored 0%)
#   adding: content/videos/ppo_halfcheetah_eval_221184.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_20480.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_2000000.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_380928.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1120256.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1161216.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_81920.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1021952.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1880064.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_342016.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_501760.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_141312.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1761280.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1820672.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1740800.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1241088.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1480704.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_880640.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_161792.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_800768.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1560576.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_481280.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_700416.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1521664.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_460800.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1200128.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_360448.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1261568.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_821248.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_540672.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_180224.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_620544.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1341440.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1701888.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1081344.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1280000.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_40960.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1861632.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1320960.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_940032.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_681984.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_561152.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_901120.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_301056.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1101824.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1441792.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1622016.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1540096.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1421312.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1380352.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_200704.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1001472.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_241664.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_100352.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_980992.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1460224.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_741376.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1681408.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_720896.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1300480.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1941504.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1181696.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1800192.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1961984.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1640448.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_960512.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_421888.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1980416.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1501184.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_520192.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_841728.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_321536.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_641024.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1400832.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1581056.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1921024.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1220608.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1841152.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1060864.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_401408.mp4 (deflated 0%)
#   adding: content/videos/ppo_halfcheetah_eval_440320.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_860160.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_581632.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_661504.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_761856.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_921600.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_600064.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1601536.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1781760.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1361920.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_61440.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1140736.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1040384.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_780288.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1720320.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1900544.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_280576.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_120832.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_1660928.mp4 (deflated 1%)
#   adding: content/videos/ppo_halfcheetah_eval_260096.mp4 (deflated 1%)

# %%
files.download('/content/videos.zip')
